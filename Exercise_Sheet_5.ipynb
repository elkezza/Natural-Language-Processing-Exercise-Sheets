# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 5

# %%
#imports for all exercises
import nltk
from nltk.corpus import brown
from nltk import FreqDist
from collections import Counter, defaultdict

# %% [markdown]
# ### Exercise 1
#
# Produce a sorted list of tags used in the Brown corpus, removing duplicates. Do the same for the universal part-of-speech tagset.

# %%
first_sentence = brown.tagged_sents()[0]

print(first_sentence)
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')]

# %% [markdown]
# #### Tags through an example
#
# - I/PRP run/VB fast/.
# - You/PRP run/VB slow/RB.
#
# #### The tags are
# - /PRP :  pronoun,
# - /VB : verb,
# - /RB : adverb.
#
# #### Universal Part-of-Speech Tagset
# LTK provides a "universal" tagset, contains of 12 Tags, which is a simplified set of tags that can be used in many languages and corpora.

# %%
# Get the tags from Brown corpus
brown_tags = [tag for (word, tag) in brown.tagged_words()]

# Get unique tags and sort
unique_brown_tags = sorted(set(brown_tags))

# Get the universal tags from Brown corpus
universal_tags = [tag for (word, tag) in brown.tagged_words(tagset='universal')]

# Get unique universal tags and sort
unique_universal_tags = sorted(set(universal_tags))

print("Brown Corpus Tags:", unique_brown_tags)
print("\nUniversal Tags:", unique_universal_tags)
# Out:
# Brown Corpus Tags: ["'", "''", '(', '(-HL', ')', ')-HL', '*', '*-HL', '*-NC', '*-TL', ',', ',-HL', ',-NC', ',-TL', '--', '---HL', '.', '.-HL', '.-NC', '.-TL', ':', ':-HL', ':-TL', 'ABL', 'ABN', 'ABN-HL', 'ABN-NC', 'ABN-TL', 'ABX', 'AP', 'AP$', 'AP+AP-NC', 'AP-HL', 'AP-NC', 'AP-TL', 'AT', 'AT-HL', 'AT-NC', 'AT-TL', 'AT-TL-HL', 'BE', 'BE-HL', 'BE-TL', 'BED', 'BED*', 'BED-NC', 'BEDZ', 'BEDZ*', 'BEDZ-HL', 'BEDZ-NC', 'BEG', 'BEM', 'BEM*', 'BEM-NC', 'BEN', 'BEN-TL', 'BER', 'BER*', 'BER*-NC', 'BER-HL', 'BER-NC', 'BER-TL', 'BEZ', 'BEZ*', 'BEZ-HL', 'BEZ-NC', 'BEZ-TL', 'CC', 'CC-HL', 'CC-NC', 'CC-TL', 'CC-TL-HL', 'CD', 'CD$', 'CD-HL', 'CD-NC', 'CD-TL', 'CD-TL-HL', 'CS', 'CS-HL', 'CS-NC', 'CS-TL', 'DO', 'DO*', 'DO*-HL', 'DO+PPSS', 'DO-HL', 'DO-NC', 'DO-TL', 'DOD', 'DOD*', 'DOD*-TL', 'DOD-NC', 'DOZ', 'DOZ*', 'DOZ*-TL', 'DOZ-HL', 'DOZ-TL', 'DT', 'DT$', 'DT+BEZ', 'DT+BEZ-NC', 'DT+MD', 'DT-HL', 'DT-NC', 'DT-TL', 'DTI', 'DTI-HL', 'DTI-TL', 'DTS', 'DTS+BEZ', 'DTS-HL', 'DTX', 'EX', 'EX+BEZ', 'EX+HVD', 'EX+HVZ', 'EX+MD', 'EX-HL', 'EX-NC', 'FW-*', 'FW-*-TL', 'FW-AT', 'FW-AT+NN-TL', 'FW-AT+NP-TL', 'FW-AT-HL', 'FW-AT-TL', 'FW-BE', 'FW-BER', 'FW-BEZ', 'FW-CC', 'FW-CC-TL', 'FW-CD', 'FW-CD-TL', 'FW-CS', 'FW-DT', 'FW-DT+BEZ', 'FW-DTS', 'FW-HV', 'FW-IN', 'FW-IN+AT', 'FW-IN+AT-T', 'FW-IN+AT-TL', 'FW-IN+NN', 'FW-IN+NN-TL', 'FW-IN+NP-TL', 'FW-IN-TL', 'FW-JJ', 'FW-JJ-NC', 'FW-JJ-TL', 'FW-JJR', 'FW-JJT', 'FW-NN', 'FW-NN$', 'FW-NN$-TL', 'FW-NN-NC', 'FW-NN-TL', 'FW-NN-TL-NC', 'FW-NNS', 'FW-NNS-NC', 'FW-NNS-TL', 'FW-NP', 'FW-NP-TL', 'FW-NPS', 'FW-NPS-TL', 'FW-NR', 'FW-NR-TL', 'FW-OD-NC', 'FW-OD-TL', 'FW-PN', 'FW-PP$', 'FW-PP$-NC', 'FW-PP$-TL', 'FW-PPL', 'FW-PPL+VBZ', 'FW-PPO', 'FW-PPO+IN', 'FW-PPS', 'FW-PPSS', 'FW-PPSS+HV', 'FW-QL', 'FW-RB', 'FW-RB+CC', 'FW-RB-TL', 'FW-TO+VB', 'FW-UH', 'FW-UH-NC', 'FW-UH-TL', 'FW-VB', 'FW-VB-NC', 'FW-VB-TL', 'FW-VBD', 'FW-VBD-TL', 'FW-VBG', 'FW-VBG-TL', 'FW-VBN', 'FW-VBZ', 'FW-WDT', 'FW-WPO', 'FW-WPS', 'HV', 'HV*', 'HV+TO', 'HV-HL', 'HV-NC', 'HV-TL', 'HVD', 'HVD*', 'HVD-HL', 'HVG', 'HVG-HL', 'HVN', 'HVZ', 'HVZ*', 'HVZ-NC', 'HVZ-TL', 'IN', 'IN+IN', 'IN+PPO', 'IN-HL', 'IN-NC', 'IN-TL', 'IN-TL-HL', 'JJ', 'JJ$-TL', 'JJ+JJ-NC', 'JJ-HL', 'JJ-NC', 'JJ-TL', 'JJ-TL-HL', 'JJ-TL-NC', 'JJR', 'JJR+CS', 'JJR-HL', 'JJR-NC', 'JJR-TL', 'JJS', 'JJS-HL', 'JJS-TL', 'JJT', 'JJT-HL', 'JJT-NC', 'JJT-TL', 'MD', 'MD*', 'MD*-HL', 'MD+HV', 'MD+PPSS', 'MD+TO', 'MD-HL', 'MD-NC', 'MD-TL', 'NIL', 'NN', 'NN$', 'NN$-HL', 'NN$-TL', 'NN+BEZ', 'NN+BEZ-TL', 'NN+HVD-TL', 'NN+HVZ', 'NN+HVZ-TL', 'NN+IN', 'NN+MD', 'NN+NN-NC', 'NN-HL', 'NN-NC', 'NN-TL', 'NN-TL-HL', 'NN-TL-NC', 'NNS', 'NNS$', 'NNS$-HL', 'NNS$-NC', 'NNS$-TL', 'NNS$-TL-HL', 'NNS+MD', 'NNS-HL', 'NNS-NC', 'NNS-TL', 'NNS-TL-HL', 'NNS-TL-NC', 'NP', 'NP$', 'NP$-HL', 'NP$-TL', 'NP+BEZ', 'NP+BEZ-NC', 'NP+HVZ', 'NP+HVZ-NC', 'NP+MD', 'NP-HL', 'NP-NC', 'NP-TL', 'NP-TL-HL', 'NPS', 'NPS$', 'NPS$-HL', 'NPS$-TL', 'NPS-HL', 'NPS-NC', 'NPS-TL', 'NR', 'NR$', 'NR$-TL', 'NR+MD', 'NR-HL', 'NR-NC', 'NR-TL', 'NR-TL-HL', 'NRS', 'NRS-TL', 'OD', 'OD-HL', 'OD-NC', 'OD-TL', 'PN', 'PN$', 'PN+BEZ', 'PN+HVD', 'PN+HVZ', 'PN+MD', 'PN-HL', 'PN-NC', 'PN-TL', 'PP$', 'PP$$', 'PP$-HL', 'PP$-NC', 'PP$-TL', 'PPL', 'PPL-HL', 'PPL-NC', 'PPL-TL', 'PPLS', 'PPO', 'PPO-HL', 'PPO-NC', 'PPO-TL', 'PPS', 'PPS+BEZ', 'PPS+BEZ-HL', 'PPS+BEZ-NC', 'PPS+HVD', 'PPS+HVZ', 'PPS+MD', 'PPS-HL', 'PPS-NC', 'PPS-TL', 'PPSS', 'PPSS+BEM', 'PPSS+BER', 'PPSS+BER-N', 'PPSS+BER-NC', 'PPSS+BER-TL', 'PPSS+BEZ', 'PPSS+BEZ*', 'PPSS+HV', 'PPSS+HV-TL', 'PPSS+HVD', 'PPSS+MD', 'PPSS+MD-NC', 'PPSS+VB', 'PPSS-HL', 'PPSS-NC', 'PPSS-TL', 'QL', 'QL-HL', 'QL-NC', 'QL-TL', 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-N ...
#
# Universal Tags: ['.', 'ADJ', 'ADP', 'ADV', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PRT', 'VERB', 'X']

# %% [markdown]
# ### Exercise 2
#
# Write a program to process the Brown Corpus using the universal part-of-speech tagset to find out which nouns are more common in their plural form than in their singular form. Only consider regular plurals formed with the "-s" suffix. Print an alphabetically sorted list of the nouns together with the frequencies for the singular and plural forms, one per line.

# %% [markdown]
# #### Goal:
#  From the Brown corpus, identify nouns that are more commonly used in their plural forms (ending in "-s") than in their singular forms.
#
# #### Approach:
# - We will go through the words in the corpus and count occurrences of singular and plural nouns.
# - Once we have these counts, we'll identify and list the nouns that appear more times in their plural form than in singular.

# %%
# Getting noun frequencies
noun_freq = FreqDist(word.lower() for word, tag in brown.tagged_words(tagset='universal') if tag == "NOUN")

# Filtering nouns that are more common in plural form
more_plural = [(noun, noun_freq[noun], noun_freq[noun + "s"]) 
               for noun in noun_freq 
               if noun_freq[noun + "s"] > noun_freq[noun]]

# Sorting and printing
for singular, singular_freq, plural_freq in sorted(more_plural):
    print(f"{singular}: Singular({singular_freq}), Plural({plural_freq})")
# Out:
# 2-year-old: Singular(2), Plural(3)
# aberration: Singular(3), Plural(5)
# abolitionist: Singular(1), Plural(4)
# aborigine: Singular(7), Plural(8)
# absolute: Singular(1), Plural(3)
# abstract: Singular(1), Plural(4)
# accommodation: Singular(1), Plural(8)
# accomplishment: Singular(7), Plural(10)
# acre: Singular(10), Plural(44)
# active: Singular(6), Plural(8)
# ad: Singular(5), Plural(10)
# adapter: Singular(1), Plural(2)
# addict: Singular(1), Plural(4)
# additive: Singular(3), Plural(4)
# adherent: Singular(1), Plural(5)
# adjective: Singular(2), Plural(4)
# admonition: Singular(1), Plural(3)
# adventure: Singular(13), Plural(14)
# adverb: Singular(1), Plural(2)
# advertisement: Singular(2), Plural(3)
# advertiser: Singular(1), Plural(5)
# adviser: Singular(6), Plural(12)
# advisor: Singular(1), Plural(5)
# affair: Singular(33), Plural(84)
# affiliation: Singular(4), Plural(5)
# ailment: Singular(4), Plural(6)
# airfield: Singular(5), Plural(6)
# airline: Singular(2), Plural(5)
# alien: Singular(2), Plural(3)
# allowance: Singular(16), Plural(25)
# allusion: Singular(3), Plural(5)
# almond: Singular(1), Plural(3)
# american: Singular(34), Plural(93)
# angel: Singular(18), Plural(24)
# ant: Singular(6), Plural(7)
# antagonist: Singular(3), Plural(4)
# antecedent: Singular(1), Plural(2)
# anti-semite: Singular(2), Plural(3)
# apache: Singular(1), Plural(4)
# apologie: Singular(1), Plural(4)
# appliance: Singular(5), Plural(8)
# applicant: Singular(8), Plural(10)
# appointee: Singular(2), Plural(5)
# appropriation: Singular(5), Plural(9)
# arm: Singular(93), Plural(121)
# armament: Singular(1), Plural(4)
# arrangement: Singular(34), Plural(38)
# aspect: Singular(47), Plural(64)
# aspencade: Singular(1), Plural(2)
# aspiration: Singular(3), Plural(12)
# assessor: Singular(2), Plural(20)
# asset: Singular(5), Plural(13)
# associate: Singular(7), Plural(14)
# atom: Singular(37), Plural(40)
# attribute: Singular(4), Plural(11)
# auditor: Singular(1), Plural(4)
# authorization: Singular(2), Plural(6)
# axe: Singular(6), Plural(7)
# axiom: Singular(1), Plural(2)
# azalea: Singular(2), Plural(3)
# backbend: Singular(1), Plural(2)
# backyard: Singular(2), Plural(3)
# bang: Singular(3), Plural(5)
# banker: Singular(5), Plural(15)
# banshee: Singular(1), Plural(2)
# barbarian: Singular(1), Plural(4)
# barrack: Singular(1), Plural(3)
# barricade: Singular(2), Plural(4)
# barrier: Singular(9), Plural(17)
# bastard: Singular(12), Plural(14)
# batten: Singular(3), Plural(15)
# batterie: Singular(1), Plural(3)
# bead: Singular(1), Plural(4)
# bean: Singular(5), Plural(9)
# bearden: Singular(4), Plural(5)
# bee: Singular(11), Plural(15)
# being: Singular(30), Plural(36)
# believer: Singular(4), Plural(5)
# bellow: Singular(4), Plural(7)
# belonging: Singular(1), Plural(4)
# bicep: Singular(1), Plural(3)
# bidder: Singular(2), Plural(3)
# billboard: Singular(1), Plural(2)
# binder: Singular(1), Plural(2)
# bird: Singular(31), Plural(57)
# biscuit: Singular(2), Plural(5)
# bite: Singular(3), Plural(6)
# blossom: Singular(4), Plural(7)
# blue: Singular(17), Plural(22)
# blueprint: Singular(1), Plural(2)
# bomb: Singular(33), Plural(35)
# bomber: Singular(8), Plural(22)
# bond: Singular(46), Plural(47)
# booklet: Singular(1), Plural(2)
# boot: Singular(10), Plural(20)
# bootlegger: Singular(1), Plural(2)
# bough: Singular(2), Plural(4)
# bound: Singular(3), Plural(10)
# bracket: Singular(1), Plural(2)
# brake: Singular(2), Plural(7)
# brave: Singular(1), Plural(3)
# bristle: Singular(2), Plural(3)
# broker: Singular(1), Plural(4)
# bronchiole: Singular(4), Plural(9)
# brook: Singular(3), Plural(16)
# brothel: Singular(1), Plural(2)
# bruise: Singular(2), Plural(8)
# bubble: Singular(12), Plural(13)
# buddhist: Singular(1), Plural(2)
# bug: Singular(4), Plural(7)
# bumblebee: Singular(2), Plural(10)
# bun: Singular(1), Plural(8)
# burglar: Singular(1), Plural(2)
# burn: Singular(5), Plural(21)
# bushel: Singular(1), Plural(4)
# buyer: Singular(2), Plural(5)
# byproduct: Singular(2), Plural(3)
# caller: Singular(2), Plural(3)
# calorie: Singular(1), Plural(7)
# camper: Singular(3), Plural(9)
# canadian: Singular(1), Plural(2)
# candidate: Singular(34), Plural(38)
# canon: Singular(5), Plural(6)
# card: Singular(26), Plural(36)
# carrier: Singular(9), Plural(11)
# carrot: Singular(1), Plural(4)
# cart: Singular(4), Plural(5)
# cartoon: Singular(3), Plural(6)
# catholic: Singular(1), Plural(33)
# catkin: Singular(2), Plural(5)
# cell: Singular(65), Plural(81)
# centimeter: Singular(2), Plural(8)
# channel: Singular(15), Plural(23)
# chant: Singular(1), Plural(3)
# characteristic: Singular(24), Plural(52)
# cheekbone: Singular(1), Plural(5)
# ches: Singular(1), Plural(3)
# cheyenne: Singular(2), Plural(3)
# chop: Singular(2), Plural(3)
# chore: Singular(7), Plural(16)
# christian: Singular(13), Plural(17)
# chunk: Singular(2), Plural(5)
# circumstance: Singular(15), Plural(84)
# citizen: Singular(30), Plural(86)
# classic: Singular(5), Plural(9)
# classmate: Singular(3), Plural(4)
# claw: Singular(1), Plural(3)
# cleaner: Singular(5), Plural(8)
# clement: Singular(1), Plural(3)
# clod: Singular(1), Plural(4)
# cloud: Singular(28), Plural(37)
# clove: Singular(1), Plural(2)
# collaborator: Singular(1), Plural(4)
# colleague: Singular(9), Plural(23)
# commercial: Singular(2), Plural(10)
# commitment: Singular(13), Plural(15)
# commune: Singular(3), Plural(5)
# competitor: Singular(3), Plural(10)
# complication: Singular(4), Plural(5)
# compliment: Singular(3), Plural(4)
# component: Singular(25), Plural(55)
# compound: Singular(9), Plural(15)
# comrade: Singular(4), Plural(10)
# concentrate: Singular(1), Plural(5)
# concession: Singular(3), Plural(7)
# concessionaire: Singular(2), Plural(7)
# condition: Singular(90), Plural(180)
# confederate: Singular(1), Plural(2)
# conformist: Singular(2), Plural(3)
# congratulation: Singular(1), Plural(7)
# congregationalist: Singular(2), Plural(3)
# conjugate: Singular(10), Plural(14)
# conqueror: Singular(1), Plural(2)
# consequence: Singular(30), Plural(35)
# conservative: Singular(3), Plural(4)
# consonant: Singular(2), Plural(4)
# constituent: Singular(5), Plural(10)
# contour: Singular(6), Plural(15)
# contributor: Singular(2), Plural(6)
# convert: Singular(3), Plural(5)
# cookie: Singular(3), Plural(6)
# cooperative: Singular(1), Plural(10)
# coordinate: Singular(2), Plural(5)
# cop: Singular(15), Plural(17)
# corp: Singular(1), Plural(103)
# cosmetic: Singular(1), Plural(7)
# cosmo: Singular(1), Plural(3)
# cossack: Singular(3), Plural(4)
# costume: Singular(10), Plural(18)
# counterpart: Singular(9), Plural(11)
# cowbird: Singular(1), Plural(3)
# crackpot: Singular(1), Plural(2)
# crater: Singular(2), Plural(5)
# creature: Singular(15), Plural(20)
# creeper: Singular(1), Plural(2)
# critic: Singular(25), Plural(26)
# critter: Singular(1), Plural(3)
# crusader: Singular(1), Plural(2)
# crystallite: Singular(1), Plural(3)
# cube: Singular(1), Plural(4)
# cuff: Singular(1), Plural(2)
# custom: Singular(10), Plural(18)
# customer: Singular(27), Plural(40)
# cutter: Singular(4), Plural(6)
# dam: Singular(2), Plural(3)
# dane: Singular(2), Plural(4)
# deadlines: Singular(1), Plural(2)
# dealer: Singular(25), Plural(30)
# decree: Singular(3), Plural(4)
# defect: Singular(3), Plural(13)
# defendant: Singular(6), Plural(10)
# defender: Singular(3), Plural(6)
# delegate: Singular(4), Plural(16)
# deliberation: Singular(2), Plural(7)
# deltoid: Singular(1), Plural(2)
# democrat: Singular(13), Plural(40)
# denomination: Singular(8), Plural(15)
# dependent: Singular(1), Plural(2)
# descendant: Singular(2), Plural(4)
# destroyer: Singular(2), Plural(3)
# determinant: Singular(1), Plural(2)
# dimension: Singular(14), Plural(30)
# diplomat: Singular(5), Plural(6)
# directive: Singular(2), Plural(4)
# disadvantage: Singular(4), Plural(9)
# disc: Singular(6), Plural(7)
# disciple: Singular(4), Plural(5)
# disclosure: Singular(2), Plural(4)
# dislocation: Singular(1), Plural(2)
# ditmar: Singular(1), Plural(2)
# diver: Singular(1), Plural(2)
# dividend: Singular(6), Plural(8)
# document: Singular(11), Plural(19)
# dodger: Singular(1), Plural(5)
# doing: Singular(4), Plural(6)
# doll: Singular(10), Plural(12)
# dollar: Singular(46), Plural(97)
# dolphin: Singular(1), Plural(4)
# dose: Singular(11), Plural(13)
# down: Singular(2), Plural(5)
# dragon: Singular(1), Plural(2)
# drawing: Singular(12), Plural(21)
# dresser: Singular(1), Plural(2)
# drier: Singular(1), Plural(3)
# drug: Singular(24), Plural(28)
# drum: Singular(11), Plural(15)
# duck: Singular(2), Plural(4)
# duct: Singular(1), Plural(6)
# duffer: Singular(1), Plural(2)
# dune: Singular(1), Plural(8)
# dynamic: Singular(1), Plural(4)
# dystopia: Singular(2), Plural(8)
# eagle: Singular(5), Plural(6)
# ear: Singular(29), Plural(38)
# eccentric: Singular(1), Plural(2)
# eclipse: Singular(2), Plural(4)
# egg: Singular(12), Plural(35)
# elder: Singular(6), Plural(9)
# elector: Singular(2), Plural(3)
# element: Singular(52), Plural(107)
# elephant: Singular(7), Plural(10)
# ellipsoid: Singular(1), Plural(4)
# emerald: Singular(3), Plural(6)
# emotion: Singular(34), Plural(43)
# employe: Singular(1), Plural(17)
# employee: Singular(24), Plural(66)
# employer: Singular(15), Plural(17)
# endearment: Singular(1), Plural(2)
# endowment: Singular(2), Plural(4)
# entertainer: Singular(2), Plural(3)
# enthusiast: Singular(2), Plural(3)
# enzyme: Singular(6), Plural(11)
# epicycle: Singular(1), Plural(6)
# epithet: Singular(2), Plural(7)
# error: Singular(36), Plural(44)
# escapade: Singular(1), Plural(2)
# ethic: Singular(4), Plural(19)
# european: Singular(2), Plural(5)
# event: Singular(81), Plural(101)
# evocation: Singular(1), Plural(2)
# expectation: Singular(11), Plural(23)
# expenditure: Singular(11), Plural(44)
# experiment: Singular(56), Plural(66)
# expert: Singular(19), Plural(38)
# exploit: Singular(1), Plural(4)
# explosive: Singular(1), Plural(3)
# export: Singular(8), Plural(11)
# extract: Singular(1), Plural(3)
# eye: Singular(122), Plural(401)
# eyebrow: Singular(4), Plural(9)
# eyelid: Singular(1), Plural(7)
# fabric: Singular(15), Plural(29)
# facet: Singular(2), Plural(9)
# faction: Singular(5), Plural(6)
# factor: Singular(71), Plural(105)
# fan: Singular(14), Plural(19)
# farmer: Singular(23), Plural(33)
# fat: Singular(13), Plural(19)
# favorite: Singular(4), Plural(12)
# feather: Singular(5), Plural(14)
# feature: Singular(30), Plural(75)
# fee: Singular(16), Plural(29)
# felon: Singular(1), Plural(2)
# ferraro: Singular(2), Plural(3)
# feud: Singular(1), Plural(2)
# fighter: Singular(9), Plural(16)
# filbert: Singular(1), Plural(2)
# fill-in: Singular(1), Plural(2)
# fin: Singular(2), Plural(5)
# final: Singular(1), Plural(10)
# finding: Singular(11), Plural(34)
# finger: Singular(40), Plural(66)
# firecracker: Singular(1), Plural(2)
# flame: Singular(13), Plural(14)
# flare: Singular(3), Plural(5)
# flower: Singular(22), Plural(57)
# follower: Singular(3), Plural(17)
# footstep: Singular(3), Plural(8)
# forecast: Singular(3), Plural(5)
# foreigner: Singular(4), Plural(13)
# fragment: Singular(6), Plural(10)
# franc: Singular(1), Plural(3)
# freeholder: Singular(1), Plural(3)
# friend: Singular(133), Plural(161)
# fund: Singular(62), Plural(95)
# furnishing: Singular(3), Plural(9)
# ga: Singular(1), Plural(98)
# gable: Singular(2), Plural(4)
# gadget: Singular(4), Plural(7)
# gangster: Singular(2), Plural(4)
# gasp: Singular(2), Plural(5)
# generalist: Singular(1), Plural(2)
# generalization: Singular(4), Plural(7)
# geologist: Singular(2), Plural(3)
# ghoul: Singular(1), Plural(2)
# giant: Singular(6), Plural(21)
# giggle: Singular(1), Plural(4)
# golfer: Singular(3), Plural(4)
# gram: Singular(10), Plural(18)
# grape: Singular(3), Plural(7)
# gras: Singular(2), Plural(53)
# grassland: Singular(1), Plural(6)
# greeting: Singular(4), Plural(6)
# grenade: Singular(3), Plural(6)
# grit: Singular(1), Plural(3)
# grocer: Singular(1), Plural(3)
# groove: Singular(2), Plural(3)
# grower: Singular(1), Plural(3)
# guerrilla: Singular(12), Plural(17)
# guest: Singular(39), Plural(62)
# gunner: Singular(1), Plural(2)
# gust: Singular(1), Plural(3)
# gut: Singular(1), Plural(9)
# gutter: Singular(1), Plural(2)
# gymnast: Singular(1), Plural(4)
# gynecologist: Singular(1), Plural(2)
# han: Singular(9), Plural(44)
# handstand: Singular(1), Plural(3)
# happening: Singular(2), Plural(5)
# harper: Singular(2), Plural(3)
# harris': Singular(1), Plural(2)
# headache: Singular(5), Plural(6)
# headline: Singular(4), Plural(7)
# headquarter: Singular(1), Plural(65)
# heel: Singular(9), Plural(23)
# helmet: Singular(1), Plural(2)
# hercule: Singular(1), Plural(3)
# heron: Singular(1), Plural(2)
# herpetologist: Singular(1), Plural(2)
# highland: Singular(1), Plural(6)
# highlight: Singular(2), Plural(3)
# hike: Singular(3), Plural(4)
# hinge: Singular(1), Plural(3)
# hit: Singular(12), Plural(15)
# hitter: Singular(2), Plural(4)
# honeybee: Singular(2), Plural(4)
# hoof: Singular(2), Plural(7)
# hostage: Singular(2), Plural(3)
# hour: Singular(145), Plural(174)
# hue: Singular(1), Plural(2)
# hulk: Singular(2), Plural(3)
# hydride: Singular(2), Plural(3)
# ideal: Singular(15), Plural(16)
# ill: Singular(1), Plural(9)
# immigrant: Singular(4), Plural(10)
# imperfection: Singular(1), Plural(2)
# implement: Singular(1), Plural(5)
# implication: Singular(10), Plural(22)
# improvisation: Singular(1), Plural(2)
# indian: Singular(10), Plural(32)
# indicator: Singular(8), Plural(9)
# infestation: Singular(2), Plural(4)
# inflection: Singular(3), Plural(4)
# ingredient: Singular(6), Plural(9)
# injunction: Singular(3), Plural(5)
# inmate: Singular(1), Plural(6)
# insect: Singular(14), Plural(23)
# insecticide: Singular(1), Plural(2)
# insinuation: Singular(2), Plural(3)
# installation: Singular(12), Plural(16)
# institution: Singular(41), Plural(98)
# instruction: Singular(26), Plural(35)
# intellectual: Singular(9), Plural(12)
# interface: Singular(3), Plural(5)
# interrelationship: Singular(1), Plural(2)
# interval: Singular(18), Plural(25)
# invader: Singular(1), Plural(5)
# investigator: Singular(4), Plural(13)
# investor: Singular(2), Plural(16)
# ion: Singular(6), Plural(9)
# italian: Singular(4), Plural(7)
# item: Singular(55), Plural(72)
# jacob: Singular(1), Plural(2)
# james': Singular(1), Plural(2)
# jaycee: Singular(1), Plural(3)
# jerebohm: Singular(2), Plural(3)
# jew: Singular(26), Plural(54)
# jewel: Singular(1), Plural(3)
# jowl: Singular(2), Plural(4)
# junior: Singular(17), Plural(31)
# jurist: Singular(3), Plural(4)
# kenning: Singular(1), Plural(10)
# keynote: Singular(1), Plural(2)
# knee: Singular(35), Plural(38)
# knuckle: Singular(2), Plural(7)
# kroger: Singular(2), Plural(3)
# lag: Singular(1), Plural(2)
# lament: Singular(1), Plural(2)
# lamentation: Singular(1), Plural(2)
# landmark: Singular(3), Plural(7)
# lao: Singular(17), Plural(64)
# lapel: Singular(1), Plural(2)
# leader: Singular(74), Plural(107)
# leaflet: Singular(1), Plural(3)
# leak: Singular(2), Plural(3)
# leave: Singular(10), Plural(23)
# lecture: Singular(14), Plural(15)
# leg: Singular(58), Plural(67)
# legislator: Singular(7), Plural(20)
# len: Singular(3), Plural(12)
# lewis': Singular(1), Plural(5)
# liberal: Singular(12), Plural(26)
# libertie: Singular(1), Plural(8)
# libertine: Singular(1), Plural(2)
# librarian: Singular(5), Plural(6)
# ligand: Singular(1), Plural(2)
# limit: Singular(31), Plural(37)
# limitation: Singular(10), Plural(28)
# lip: Singular(18), Plural(69)
# listener: Singular(10), Plural(20)
# litigant: Singular(2), Plural(3)
# lo: Singular(21), Plural(51)
# lobe: Singular(3), Plural(5)
# lobule: Singular(1), Plural(2)
# locale: Singular(3), Plural(4)
# lodging: Singular(1), Plural(2)
# loin: Singular(1), Plural(2)
# longhorn: Singular(4), Plural(5)
# los: Singular(51), Plural(86)
# loudspeaker: Singular(1), Plural(2)
# louis': Singular(1), Plural(2)
# lung: Singular(16), Plural(20)
# lyric: Singular(7), Plural(15)
# magpie: Singular(1), Plural(2)
# make: Singular(3), Plural(4)
# maker: Singular(12), Plural(19)
# mammal: Singular(1), Plural(3)
# mana: Singular(3), Plural(4)
# maneuver: Singular(3), Plural(8)
# manifestation: Singular(6), Plural(9)
# manual: Singular(2), Plural(4)
# manufacturer: Singular(23), Plural(47)
# map: Singular(12), Plural(13)
# mar: Singular(2), Plural(19)
# marking: Singular(1), Plural(2)
# mean: Singular(12), Plural(205)
# measurement: Singular(34), Plural(54)
# mechanic: Singular(5), Plural(19)
# meditation: Singular(2), Plural(4)
# megaton: Singular(2), Plural(10)
# member: Singular(137), Plural(325)
# memoir: Singular(2), Plural(4)
# merchant: Singular(20), Plural(22)
# metaphysic: Singular(3), Plural(12)
# meteor: Singular(3), Plural(4)
# meteorite: Singular(6), Plural(8)
# meter: Singular(6), Plural(11)
# mexican: Singular(5), Plural(12)
# microorganism: Singular(1), Plural(12)
# mile: Singular(48), Plural(173)
# mill: Singular(11), Plural(32)
# milligram: Singular(5), Plural(21)
# mine: Singular(21), Plural(28)
# miner: Singular(1), Plural(5)
# mineral: Singular(12), Plural(14)
# minute: Singular(44), Plural(196)
# moccasin: Singular(1), Plural(2)
# modification: Singular(4), Plural(6)
# molecule: Singular(6), Plural(9)
# monosyllable: Singular(1), Plural(2)
# month: Singular(130), Plural(189)
# moral: Singular(5), Plural(7)
# mose: Singular(6), Plural(9)
# moth: Singular(1), Plural(2)
# motorist: Singular(2), Plural(5)
# mountain: Singular(33), Plural(43)
# movie: Singular(29), Plural(31)
# mug: Singular(1), Plural(2)
# musician: Singular(23), Plural(41)
# mystic: Singular(1), Plural(3)
# nail: Singular(6), Plural(14)
# narcotic: Singular(1), Plural(7)
# nation: Singular(139), Plural(175)
# national: Singular(3), Plural(4)
# native: Singular(10), Plural(11)
# negotiation: Singular(6), Plural(20)
# neighbor: Singular(14), Plural(40)
# nerve: Singular(12), Plural(22)
# newlywed: Singular(1), Plural(2)
# nightclub: Singular(2), Plural(4)
# nikolai: Singular(2), Plural(4)
# nomia: Singular(1), Plural(2)
# norm: Singular(10), Plural(24)
# northerner: Singular(4), Plural(5)
# nostril: Singular(1), Plural(3)
# noun: Singular(1), Plural(3)
# nuance: Singular(1), Plural(3)
# nun: Singular(2), Plural(4)
# nut: Singular(15), Plural(20)
# object: Singular(53), Plural(62)
# obligation: Singular(16), Plural(21)
# observation: Singular(27), Plural(40)
# observer: Singular(16), Plural(20)
# occupant: Singular(4), Plural(9)
# official: Singular(20), Plural(62)
# oilseed: Singular(1), Plural(4)
# orchard: Singular(3), Plural(5)
# organ: Singular(12), Plural(14)
# organism: Singular(6), Plural(7)
# oriole: Singular(5), Plural(11)
# outbreak: Singular(2), Plural(3)
# outburst: Singular(2), Plural(6)
# outsider: Singular(3), Plural(8)
# overall: Singular(2), Plural(5)
# overhang: Singular(1), Plural(2)
# owner: Singular(33), Plural(35)
# oyster: Singular(6), Plural(8)
# pacer: Singular(1), Plural(3)
# painting: Singular(27), Plural(36)
# pajama: Singular(1), Plural(3)
# pamphlet: Singular(2), Plural(9)
# panel: Singular(31), Plural(46)
# paragraph: Singular(12), Plural(14)
# parameter: Singular(7), Plural(8)
# parasite: Singular(1), Plural(4)
# parent: Singular(15), Plural(91)
# parson: Singular(2), Plural(5)
# participant: Singular(4), Plural(7)
# particle: Singular(21), Plural(42)
# passenger: Singular(14), Plural(21)
# patron: Singular(4), Plural(9)
# paw: Singular(2), Plural(3)
# peacock: Singular(2), Plural(4)
# peasant: Singular(7), Plural(12)
# pebble: Singular(1), Plural(3)
# peer: Singular(6), Plural(7)
# peptide: Singular(1), Plural(2)
# performer: Singular(7), Plural(13)
# periodical: Singular(4), Plural(5)
# persian: Singular(1), Plural(12)
# personage: Singular(1), Plural(3)
# perturbation: Singular(1), Plural(2)
# pheasant: Singular(1), Plural(2)
# phillip: Singular(2), Plural(11)
# photo: Singular(5), Plural(7)
# photographer: Singular(5), Plural(6)
# picker: Singular(1), Plural(3)
# pier: Singular(3), Plural(6)
# pilgrim: Singular(4), Plural(6)
# pillar: Singular(2), Plural(5)
# pink: Singular(1), Plural(2)
# pirate: Singular(4), Plural(12)
# plain: Singular(7), Plural(14)
# planet: Singular(21), Plural(22)
# planner: Singular(2), Plural(13)
# plaque: Singular(2), Plural(4)
# plastic: Singular(25), Plural(31)
# plate: Singular(22), Plural(23)
# poem: Singular(48), Plural(82)
# politician: Singular(13), Plural(19)
# poll: Singular(9), Plural(10)
# polymer: Singular(1), Plural(4)
# polyphosphate: Singular(1), Plural(5)
# pop: Singular(4), Plural(10)
# pore: Singular(2), Plural(3)
# potter: Singular(4), Plural(8)
# pound: Singular(26), Plural(44)
# practitioner: Singular(2), Plural(6)
# precept: Singular(1), Plural(3)
# predecessor: Singular(5), Plural(6)
# predisposition: Singular(4), Plural(9)
# premise: Singular(7), Plural(8)
# prerogative: Singular(1), Plural(2)
# preserve: Singular(4), Plural(8)
# princes: Singular(3), Plural(10)
# prisoner: Singular(7), Plural(21)
# probe: Singular(1), Plural(3)
# proceeding: Singular(5), Plural(18)
# product: Singular(87), Plural(108)
# professional: Singular(6), Plural(10)
# progression: Singular(2), Plural(3)
# projection: Singular(9), Plural(10)
# promoter: Singular(1), Plural(4)
# prop: Singular(2), Plural(6)
# propagandist: Singular(3), Plural(4)
# proponent: Singular(2), Plural(6)
# protease: Singular(1), Plural(4)
# protestant: Singular(3), Plural(14)
# psychiatrist: Singular(4), Plural(5)
# psychologist: Singular(10), Plural(11)
# publisher: Singular(9), Plural(11)
# puddle: Singular(1), Plural(2)
# pupil: Singular(20), Plural(25)
# purge: Singular(1), Plural(2)
# push-up: Singular(3), Plural(4)
# qualification: Singular(8), Plural(16)
# quotation: Singular(4), Plural(5)
# race-driver: Singular(3), Plural(4)
# racketeer: Singular(2), Plural(3)
# ramification: Singular(1), Plural(3)
# rating: Singular(6), Plural(9)
# rattlesnake: Singular(3), Plural(5)
# rdw: Singular(2), Plural(4)
# reagent: Singular(1), Plural(3)
# realtor: Singular(5), Plural(19)
# reb: Singular(2), Plural(5)
# rebel: Singular(15), Plural(16)
# receipt: Singular(4), Plural(7)
# recrimination: Singular(1), Plural(3)
# recruit: Singular(1), Plural(8)
# redcoat: Singular(6), Plural(9)
# referral: Singular(6), Plural(8)
# regulation: Singular(14), Plural(29)
# rein: Singular(3), Plural(9)
# reinforcement: Singular(2), Plural(3)
# relation: Singular(63), Plural(102)
# relative: Singular(1), Plural(22)
# remark: Singular(29), Plural(46)
# rendition: Singular(1), Plural(3)
# reporter: Singular(20), Plural(34)
# representative: Singular(29), Plural(41)
# repulsion: Singular(1), Plural(2)
# requirement: Singular(27), Plural(83)
# researcher: Singular(3), Plural(4)
# reservation: Singular(8), Plural(9)
# resident: Singular(8), Plural(20)
# resistor: Singular(3), Plural(7)
# resource: Singular(9), Plural(72)
# restriction: Singular(8), Plural(27)
# resultant: Singular(1), Plural(5)
# retailer: Singular(1), Plural(5)
# revision: Singular(8), Plural(9)
# rib: Singular(1), Plural(11)
# riddle: Singular(1), Plural(2)
# rim-fire: Singular(2), Plural(3)
# ripple: Singular(4), Plural(5)
# robber: Singular(2), Plural(6)
# robot: Singular(1), Plural(3)
# rocket: Singular(7), Plural(13)
# rogue: Singular(1), Plural(2)
# romantic: Singular(1), Plural(5)
# roommate: Singular(1), Plural(2)
# rule: Singular(66), Plural(82)
# ruler: Singular(3), Plural(9)
# runner: Singular(1), Plural(5)
# rupee: Singular(6), Plural(14)
# russian: Singular(11), Plural(31)
# rut: Singular(1), Plural(2)
# sacrament: Singular(1), Plural(2)
# sailboat: Singular(1), Plural(3)
# sailor: Singular(5), Plural(8)
# sale: Singular(44), Plural(133)
# salon: Singular(1), Plural(3)
# sausage: Singular(1), Plural(5)
# savage: Singular(3), Plural(6)
# saving: Singular(3), Plural(23)
# scholar: Singular(15), Plural(27)
# schoolmate: Singular(1), Plural(2)
# scientist: Singular(17), Plural(36)
# scot: Singular(1), Plural(8)
# scripture: Singular(4), Plural(11)
# secant: Singular(12), Plural(16)
# sedan: Singular(2), Plural(4)
# sediment: Singular(3), Plural(4)
# seed: Singular(40), Plural(42)
# seeker: Singular(1), Plural(3)
# sensor: Singular(3), Plural(6)
# serpent: Singular(2), Plural(3)
# servant: Singular(19), Plural(22)
# settler: Singular(3), Plural(12)
# shaker: Singular(2), Plural(3)
# shareholder: Singular(1), Plural(3)
# shipment: Singular(2), Plural(16)
# shoe: Singular(14), Plural(44)
# short: Singular(3), Plural(29)
# shortcut: Singular(1), Plural(2)
# shred: Singular(1), Plural(5)
# shrub: Singular(1), Plural(4)
# shunt: Singular(1), Plural(5)
# si: Singular(1), Plural(3)
# silhouette: Singular(4), Plural(5)
# silo: Singular(1), Plural(2)
# singer: Singular(10), Plural(13)
# siren: Singular(1), Plural(2)
# skipper: Singular(1), Plural(2)
# skylight: Singular(1), Plural(2)
# slack: Singular(3), Plural(7)
# slave: Singular(30), Plural(44)
# slipper: Singular(3), Plural(7)
# sneaker: Singular(2), Plural(3)
# sock: Singular(3), Plural(7)
# soldier: Singular(39), Plural(56)
# sole: Singular(2), Plural(5)
# solid: Singular(7), Plural(13)
# somersault: Singular(2), Plural(3)
# soothsayer: Singular(1), Plural(2)
# southerner: Singular(8), Plural(26)
# soybean: Singular(5), Plural(6)
# spacer: Singular(2), Plural(5)
# specialist: Singular(16), Plural(19)
# specification: Singular(3), Plural(9)
# spectator: Singular(9), Plural(13)
# speculation: Singular(3), Plural(4)
# speculator: Singular(1), Plural(2)
# spice: Singular(2), Plural(3)
# spike: Singular(1), Plural(3)
# spoke: Singular(1), Plural(2)
# sport: Singular(17), Plural(48)
# spouse: Singular(3), Plural(4)
# stain: Singular(4), Plural(9)
# stair: Singular(2), Plural(47)
# stamp: Singular(3), Plural(4)
# standard: Singular(31), Plural(74)
# star: Singular(25), Plural(29)
# step: Singular(110), Plural(118)
# steroid: Singular(1), Plural(2)
# stockholder: Singular(2), Plural(26)
# strap: Singular(1), Plural(2)
# stray: Singular(1), Plural(6)
# stripe: Singular(4), Plural(5)
# striving: Singular(1), Plural(3)
# student: Singular(131), Plural(213)
# stump: Singular(2), Plural(5)
# submarine: Singular(15), Plural(20)
# subordinate: Singular(1), Plural(9)
# subsystem: Singular(2), Plural(10)
# suburb: Singular(13), Plural(18)
# suitor: Singular(1), Plural(3)
# sultan: Singular(3), Plural(4)
# superior: Singular(1), Plural(4)
# supermarket: Singular(1), Plural(3)
# supporter: Singular(3), Plural(8)
# surfactant: Singular(1), Plural(2)
# survivalist: Singular(1), Plural(2)
# survivor: Singular(1), Plural(13)
# swell: Singular(1), Plural(4)
# swelling: Singular(1), Plural(2)
# syllable: Singular(1), Plural(9)
# symptom: Singular(5), Plural(14)
# tablespoon: Singular(6), Plural(7)
# tactic: Singular(4), Plural(20)
# tangent: Singular(4), Plural(6)
# tank: Singular(12), Plural(18)
# tanker: Singular(1), Plural(2)
# tara: Singular(1), Plural(3)
# tavern: Singular(2), Plural(4)
# taxpayer: Singular(11), Plural(21)
# teamster: Singular(1), Plural(8)
# tear: Singular(2), Plural(34)
# technician: Singular(6), Plural(12)
# technique: Singular(60), Plural(99)
# teen-ager: Singular(2), Plural(12)
# teenager: Singular(2), Plural(5)
# tektite: Singular(1), Plural(5)
# telegrapher: Singular(3), Plural(5)
# tenant: Singular(5), Plural(9)
# tenement: Singular(2), Plural(3)
# tentacle: Singular(1), Plural(2)
# term: Singular(76), Plural(160)
# terminal: Singular(3), Plural(4)
# texan: Singular(4), Plural(9)
# theologian: Singular(5), Plural(9)
# thicket: Singular(1), Plural(2)
# thing: Singular(333), Plural(368)
# third: Singular(2), Plural(4)
# thug: Singular(1), Plural(2)
# tick: Singular(1), Plural(2)
# tidbit: Singular(1), Plural(2)
# toe: Singular(7), Plural(19)
# ton: Singular(13), Plural(28)
# tonic: Singular(1), Plural(2)
# topic: Singular(9), Plural(10)
# towel: Singular(6), Plural(11)
# toy: Singular(4), Plural(10)
# trader: Singular(8), Plural(26)
# trailer: Singular(11), Plural(12)
# trait: Singular(3), Plural(6)
# traitor: Singular(2), Plural(4)
# tranquilizer: Singular(1), Plural(4)
# transformer: Singular(1), Plural(2)
# treasure: Singular(4), Plural(6)
# tree: Singular(59), Plural(101)
# tribe: Singular(4), Plural(12)
# trimming: Singular(1), Plural(4)
# triplet: Singular(1), Plural(3)
# troop: Singular(16), Plural(53)
# trouser: Singular(3), Plural(7)
# trustee: Singular(9), Plural(25)
# twin: Singular(6), Plural(12)
# undergraduate: Singular(4), Plural(9)
# underwriter: Singular(1), Plural(4)
# uprising: Singular(1), Plural(2)
# user: Singular(4), Plural(6)
# utopian: Singular(2), Plural(5)
# valve: Singular(3), Plural(4)
# variable: Singular(11), Plural(26)
# vase: Singular(4), Plural(11)
# vault: Singular(2), Plural(6)
# vegetable: Singular(10), Plural(16)
# vehicle: Singular(35), Plural(53)
# vendor: Singular(1), Plural(2)
# verb: Singular(4), Plural(7)
# villain: Singular(3), Plural(4)
# vine: Singular(4), Plural(8)
# vineyard: Singular(2), Plural(5)
# visitor: Singular(13), Plural(36)
# vitamin: Singular(5), Plural(10)
# volunteer: Singular(5), Plural(29)
# voter: Singular(4), Plural(20)
# vow: Singular(2), Plural(4)
# wandering: Singular(1), Plural(3)
# warrior: Singular(5), Plural(7)
# watershed: Singular(3), Plural(4)
# waterway: Singular(2), Plural(3)
# wave: Singular(44), Plural(51)
# wavelength: Singular(4), Plural(6)
# weapon: Singular(42), Plural(61)
# weave: Singular(1), Plural(2)
# williams': Singular(1), Plural(2)
# win: Singular(1), Plural(3)
# wing: Singular(17), Plural(27)
# worker: Singular(30), Plural(86)
# worm: Singular(4), Plural(5)
# wrinkle: Singular(2), Plural(7)
# yankee: Singular(10), Plural(28)
# yard: Singular(35), Plural(64)
# year: Singular(656), Plural(949)
# youngster: Singular(8), Plural(18)

# %% [markdown]
# ### Exercise 3
#
# Find out which word has the greatest number of distinct tags in the Brown corpus using the original tagset. Without using the `most_common` function, print a list of the tags together with the frequencies for the word, sorted by frequency from highest to lowest, one per line.

# %% [markdown]
# #### Goal:
# - Identify the word in the Brown corpus that is tagged with the most number of unique tags.
# - Display the tags and their respective frequencies for this word.

# %%
# 1- Create a dictionary to track tags for each word
  #Initializing a dictionary (tags_dict) where keys are words and values are sets. Sets are used to store unique tags for each word without duplicates.
tags_dict = defaultdict(set)
 
# 2-  Iterating over each (word, tag) tuple in the Brown corpus.
for word, tag in brown.tagged_words():
    #Converting the word to lowercase to ensure uniformity.
    # Adding the tag to the set corresponding to the word in the tags_dict. 
    # If a word has the same tag multiple times, the set will store it only once.
    tags_dict[word.lower()].add(tag)

# 3- Find the word with the maximum number of distinct tags
max_word = max(tags_dict, key=lambda k: len(tags_dict[k])) # The max function is used with a custom key function to get the word associated with the largest set of tags.
max_tags = tags_dict[max_word] # Storing the set of unique tags associated with the max_word in the variable max_tags.

# 4- Get frequencies of tags for the max_word

# Creating a counter object (word_tags_original) to count occurrences of each (word, tag) tuple in the Brown corpus. This will help us find the frequency of each tag for the max_word.
word_tags_original = Counter([(word.lower(), tag) for (word, tag) in brown.tagged_words()])

# Creating a list of tuples (tags_frequencies), where each tuple contains a tag and its frequency for the max_word.
# This list is derived from the max_tags set and the word_tags_original counter.
tags_frequencies = [(tag, word_tags_original[(max_word, tag)]) for tag in max_tags]

# 5- Sort and print tags by frequency

# Sorting the tags_frequencies list based on the frequencies of the tags in descending order.
tags_frequencies.sort(key=lambda x: x[1], reverse=True)

print(f"The word '{max_word}' has  {len(max_tags)}  distinct tags.")


# Iterating over each (tag, frequency) tuple in the sorted tags_frequencies list and printing them.
for tag, freq in tags_frequencies:
    print(tag, freq)
# Out:
# The word 'that' has  15  distinct tags.
# CS 6464
# DT 2260
# WPS 1654
# WPO 135
# QL 56
# DT-NC 6
# DT-TL 5
# WPS-TL 3
# WPS-NC 3
# CS-NC 2
# WPS-HL 2
# NIL 1
# WPO-NC 1
# CS-HL 1
# DT-HL 1

# %%
word_tags = defaultdict(set)

# Extracting word-tag combinations from Brown corpus
for word, tag in brown.tagged_words():
    word_tags[word].add(tag)

# Finding word with maximum distinct tags
max_word = max(word_tags, key=lambda x: len(word_tags[x]))

tags_frequency = {tag: sum(1 for _, t in brown.tagged_words() if t == tag and _ == max_word) 
                  for tag in word_tags[max_word]}

# Sorting by frequency and printing
for tag, freq in sorted(tags_frequency.items(), key=lambda x: x[1], reverse=True):
    print(f"{tag}: {freq}")
# Out:
# CS: 6419
# DT: 1975
# WPS: 1638
# WPO: 135
# QL: 54
# DT-NC: 6
# WPS-NC: 3
# CS-NC: 2
# WPS-HL: 2
# NIL: 1
# WPO-NC: 1
# CS-HL: 1

# %% [markdown]
# ### Exercise 4
#
# Tabulate the frequencies of the universal tags that precede nouns in the Brown Corpus.

# %% [markdown]
# #### Goal:
# We want see which tags often come before nouns in the Brown Corpus
#
# #### Approach:
# - Go through the Brown Corpus word by word.
# - Whenever you find a noun, note down the tag of the word that comes before it.
# - Count the occurrences of each tag that precedes nouns.

# %%
# Define a default dictionary to hold frequencies of tags preceding nouns
preceding_tags = defaultdict(int)

# Using universal tagset for simplicity
# We use the brown.tagged_words function with the 'universal' tagset to get words along with their simplified tags.tagged_words = list(brown.tagged_words(tagset='universal'))

# Iterate over the tagged words with an index
for i, (word, tag) in enumerate(tagged_words):
    # Check if the word is a noun
    if tag == "NOUN" and i > 0:  # Whenever we find a noun, 
        preceding_tag = tagged_words[i-1][1] # we look at the word just before it, and note down its tag.
        preceding_tags[preceding_tag] += 1   # increment the count of the given tag by 1

# Display the frequencies
for tag, count in sorted(preceding_tags.items(), key=lambda x: x[1], reverse=True):
    print(tag, count)
# Out:
# DET 85845
# ADJ 54653
# NOUN 41309
# ADP 37418
# . 20084
# VERB 17851
# CONJ 9294
# NUM 5668
# ADV 1851
# PRT 1068
# PRON 440
# X 77

# %% [markdown]
# ### Exercise 5
#
# Write a function `ambiguous(tagged_text)` that returns the number of ambiguous word types as well as the number of all word types in a tagged text. A word type is ambiguous if it is tagged with at least two different tags. Use the function to print both values as well as the percentage of ambiguous word types for the Brown Corpus both for the original and the universal tagset.

# %% [markdown]
# #### Goal:
# - Create Funcation "ambiguous(tagged_text)", calculates how many words in tagged text have more than one tag
# - We want to find words that have been labeled with more than one tag
#
# #### Approach:
# - For each word, we'll see how many different tags it has. If a word has more than one tag, it's ambiguous.

# %%
def ambiguous(tagged_text):
    # This dictionary will store each word as a key. 
    # The value will be a set containing all unique tags the word is associated with.
    word_tags = defaultdict(set)
    
    # Populating the word_tags dictionary
    for word, tag in tagged_text:
        word_tags[word.lower()].add(tag)  # We convert word to lowercase to ensure consistency

    # Counting the number of ambiguous words - those with more than 1 tag
    ambiguous_words = sum(1 for tags in word_tags.values() if len(tags) > 1)

    # Total unique words
    total_words = len(word_tags)

    # Percentage of ambiguous words
    percentage_ambiguous = (ambiguous_words / total_words) * 100

    # Printing the results
    print(f"Number of Ambiguous Word Types: {ambiguous_words}")
    print(f"Total Number of Word Types: {total_words}")
    print(f"Percentage of Ambiguous Word Types: {percentage_ambiguous:.2f}%")

    return ambiguous_words, total_words

# Using the function for the Brown Corpus with the original tagset
print("Original Tagset:")
ambiguous(brown.tagged_words())

# Using the function for the Brown Corpus with the universal tagset
print("\nUniversal Tagset:")
ambiguous(brown.tagged_words(tagset='universal'))
# Out:
# Original Tagset:
# Number of Ambiguous Word Types: 9580
# Total Number of Word Types: 49815
# Percentage of Ambiguous Word Types: 19.23%
#
# Universal Tagset:
# Number of Ambiguous Word Types: 3408
# Total Number of Word Types: 49815
# Percentage of Ambiguous Word Types: 6.84%
# (3408, 49815)

# %% [markdown]
# ### Exercise 6
#
# Write code to search the Brown Corpus to answer the following questions:

# %% [markdown]
# a) produce an alphabetically sorted list of the distinct words tagged as `MD`

# %%
# Extracting words tagged as MD
md_words = {word.lower() for word, tag in brown.tagged_words() if tag == 'MD'}

# Sorting and printing the words
print(sorted(md_words))
# Out:
# ["c'n", 'can', 'colde', 'could', 'dare', 'kin', 'maht', 'mai', 'may', 'maye', 'mayst', 'might', 'must', 'need', 'ought', 'shall', 'should', 'shuld', 'shulde', 'wil', 'will', 'wilt', 'wod', 'wold', 'wolde', 'would']

# %% [markdown]
# b) identify words that can be plural nouns or third person singular verbs

# %%
# Initializing an empty set
word_tag_set = set()

# Iterating over each word, tag pair in the Brown corpus
for word, tag in brown.tagged_words():
    # If the tag is 'NNS' or 'VBZ'
    if tag in ['NNS', 'VBZ']:
        # Adding a tuple (word, tag) to the set
        word_tag_set.add((word.lower(), tag))

# Sorting the set primarily by word, then by tag
sorted_word_tags = sorted(word_tag_set, key=lambda x: (x[0], x[1]))

# Displaying the sorted list
for item in sorted_word_tags:
    print(item)
# Out:
# ('$.027', 'NNS')
# ('$.03', 'NNS')
# ('$.054/mbf', 'NNS')
# ('$.07', 'NNS')
# ('$.07/cwt', 'NNS')
# ('$.076', 'NNS')
# ('$.09', 'NNS')
# ('$.105', 'NNS')
# ('$.12', 'NNS')
# ('$.30', 'NNS')
# ('$.30/mbf', 'NNS')
# ('$.50', 'NNS')
# ('$.65', 'NNS')
# ('$.75', 'NNS')
# ('$.80', 'NNS')
# ('$.86', 'NNS')
# ('$.90', 'NNS')
# ('$0.9', 'NNS')
# ('$1', 'NNS')
# ('$1,000', 'NNS')
# ('$1,000,000', 'NNS')
# ('$1,000,000,000', 'NNS')
# ('$1,200', 'NNS')
# ('$1,250,000', 'NNS')
# ('$1,276', 'NNS')
# ('$1,390', 'NNS')
# ('$1,450,000,000', 'NNS')
# ('$1,500', 'NNS')
# ('$1,500,000', 'NNS')
# ('$1,600', 'NNS')
# ('$1,750,000', 'NNS')
# ('$1,800', 'NNS')
# ('$1,961,000', 'NNS')
# ('$1.0', 'NNS')
# ('$1.1', 'NNS')
# ('$1.10', 'NNS')
# ('$1.26', 'NNS')
# ('$1.4', 'NNS')
# ('$1.5', 'NNS')
# ('$1.6', 'NNS')
# ('$1.60', 'NNS')
# ('$1.65', 'NNS')
# ('$1.7', 'NNS')
# ('$1.8', 'NNS')
# ('$1.80', 'NNS')
# ('$1.9', 'NNS')
# ('$10', 'NNS')
# ('$10,000', 'NNS')
# ('$10,000,000', 'NNS')
# ('$10,000-per-year', 'NNS')
# ('$10.00', 'NNS')
# ('$10.1', 'NNS')
# ('$10.3', 'NNS')
# ('$10.50', 'NNS')
# ('$10.8', 'NNS')
# ('$100', 'NNS')
# ('$100,000', 'NNS')
# ('$102,285,000', 'NNS')
# ('$1020', 'NNS')
# ('$109', 'NNS')
# ('$11', 'NNS')
# ('$11,900,000', 'NNS')
# ('$11.50', 'NNS')
# ('$110', 'NNS')
# ('$115,000', 'NNS')
# ('$12', 'NNS')
# ('$12,192,865', 'NNS')
# ('$12,500', 'NNS')
# ('$12.00', 'NNS')
# ('$12.1', 'NNS')
# ('$12.50', 'NNS')
# ('$12.7', 'NNS')
# ('$120', 'NNS')
# ('$125', 'NNS')
# ('$128', 'NNS')
# ('$133', 'NNS')
# ('$135', 'NNS')
# ('$139.3', 'NNS')
# ('$14', 'NNS')
# ('$14,000', 'NNS')
# ('$14.00', 'NNS')
# ('$140', 'NNS')
# ('$148.50', 'NNS')
# ('$15', 'NNS')
# ('$15,000', 'NNS')
# ('$15,000,000', 'NNS')
# ('$15.5', 'NNS')
# ('$150', 'NNS')
# ('$1500', 'NNS')
# ('$157,460', 'NNS')
# ('$16', 'NNS')
# ('$16,000', 'NNS')
# ('$16.00', 'NNS')
# ('$16.80', 'NNS')
# ('$165', 'NNS')
# ('$17', 'NNS')
# ('$17,000', 'NNS')
# ('$17,000,000', 'NNS')
# ('$17.8', 'NNS')
# ('$170', 'NNS')
# ('$172,000', 'NNS')
# ('$172,400', 'NNS')
# ('$18', 'NNS')
# ('$18.2', 'NNS')
# ('$18.9', 'NNS')
# ('$184', 'NNS')
# ('$185', 'NNS')
# ('$187', 'NNS')
# ('$19.3', 'NNS')
# ('$2', 'NNS')
# ('$2,000', 'NNS')
# ('$2,000,000', 'NNS')
# ('$2,170', 'NNS')
# ('$2,300', 'NNS')
# ('$2,300,000', 'NNS')
# ('$2,323,867', 'NNS')
# ('$2,330,000', 'NNS')
# ('$2,412,616', 'NNS')
# ('$2,461,000', 'NNS')
# ('$2,490', 'NNS')
# ('$2,500', 'NNS')
# ('$2,557,111', 'NNS')
# ('$2,700', 'NNS')
# ('$2.00', 'NNS')
# ('$2.09', 'NNS')
# ('$2.30/mbf', 'NNS')
# ('$2.50', 'NNS')
# ('$2.80', 'NNS')
# ('$2.82', 'NNS')
# ('$2.98', 'NNS')
# ('$20', 'NNS')
# ('$20,000', 'NNS')
# ('$20,000,000', 'NNS')
# ('$20,000,000,000', 'NNS')
# ('$20,447,000', 'NNS')
# ('$200', 'NNS')
# ('$200,000', 'NNS')
# ('$200,000,000', 'NNS')
# ('$200,000-a-year', 'NNS')
# ('$214', 'NNS')
# ('$22', 'NNS')
# ('$22.50', 'NNS')
# ('$222', 'NNS')
# ('$227.72', 'NNS')
# ('$23,000,000', 'NNS')
# ('$230,000', 'NNS')
# ('$24,926,615', 'NNS')
# ('$2400', 'NNS')
# ('$25', 'NNS')
# ('$25,000', 'NNS')
# ('$250', 'NNS')
# ('$250,000', 'NNS')
# ('$2500', 'NNS')
# ('$251', 'NNS')
# ('$253,355,000', 'NNS')
# ('$26,000,000', 'NNS')
# ('$26.5-billion', 'NNS')
# ('$27.50', 'NNS')
# ('$278,877,000', 'NNS')
# ('$28', 'NNS')
# ('$28,700,000', 'NNS')
# ('$28.00', 'NNS')
# ('$29', 'NNS')
# ('$29,000', 'NNS')
# ('$297', 'NNS')
# ('$3', 'NNS')
# ('$3,000', 'NNS')
# ('$3,500', 'NNS')
# ('$3,500,000', 'NNS')
# ('$3,675', 'NNS')
# ('$3,825', 'NNS')
# ('$3.00', 'NNS')
# ('$3.11', 'NNS')
# ('$3.15', 'NNS')
# ('$3.22', 'NNS')
# ('$3.5', 'NNS')
# ('$3.50', 'NNS')
# ('$30', 'NNS')
# ('$30,000', 'NNS')
# ('$30,000,000', 'NNS')
# ('$300', 'NNS')
# ('$300,000', 'NNS')
# ('$300,000,000', 'NNS')
# ('$306', 'NNS')
# ('$31,179,816', 'NNS')
# ('$310', 'NNS')
# ('$3100', 'NNS')
# ('$32,000', 'NNS')
# ('$325', 'NNS')
# ('$344,000', 'NNS')
# ('$35', 'NNS')
# ('$35,823', 'NNS')
# ('$350', 'NNS')
# ('$350,000', 'NNS')
# ('$36', 'NNS')
# ('$37', 'NNS')
# ('$37,500', 'NNS')
# ('$380', 'NNS')
# ('$39,000', 'NNS')
# ('$39.5', 'NNS')
# ('$395,000', 'NNS')
# ('$4', 'NNS')
# ('$4,000', 'NNS')
# ('$4,000,000', 'NNS')
# ('$4,177.37', 'NNS')
# ('$4,500', 'NNS')
# ('$4,500,000', 'NNS')
# ('$4,700', 'NNS')
# ('$4,753', 'NNS')
# ('$4,800', 'NNS')
# ('$4.9', 'NNS')
# ('$4.98', 'NNS')
# ('$4/mbf', 'NNS')
# ('$40', 'NNS')
# ('$40,000', 'NNS')
# ('$40,000,000', 'NNS')
# ('$400', 'NNS')
# ('$4200', 'NNS')
# ('$43,000', 'NNS')
# ('$43.50', 'NNS')
# ('$44.3-billion', 'NNS')
# ('$45', 'NNS')
# ('$450', 'NNS')
# ('$450,000', 'NNS')
# ('$451,500', 'NNS')
# ('$457,000', 'NNS')
# ('$46.7', 'NNS')
# ('$47,101,000', 'NNS')
# ('$5', 'NNS')
# ('$5,000', 'NNS')
# ('$5,000,000', 'NNS')
# ('$5-8,000', 'NNS')
# ('$5.2', 'NNS')
# ('$5.4', 'NNS')
# ('$50', 'NNS')
# ('$50,000', 'NNS')
# ('$50,400,000', 'NNS')
# ('$500', 'NNS')
# ('$500,000', 'NNS')
# ('$5000', 'NNS')
# ('$52,500', 'NNS')
# ('$538', 'NNS')
# ('$55,000', 'NNS')
# ('$550', 'NNS')
# ('$56', 'NNS')
# ('$57,500', 'NNS')
# ('$58,918', 'NNS')
# ('$580', 'NNS')
# ('$581', 'NNS')
# ('$581,000', 'NNS')
# ('$590,000', 'NNS')
# ('$6', 'NNS')
# ('$6,100,000,000', 'NNS')
# ('$6,666.66', 'NNS')
# ('$60', 'NNS')
# ('$60,000', 'NNS')
# ('$600', 'NNS')
# ('$610', 'NNS')
# ('$625,561', 'NNS')
# ('$63.8', 'NNS')
# ('$634,517,000', 'NNS')
# ('$639', 'NNS')
# ('$65', 'NNS')
# ('$65,000', 'NNS')
# ('$650', 'NNS')
# ('$66,000', 'NNS')
# ('$67,000', 'NNS')
# ('$7', 'NNS')
# ('$7,000', 'NNS')
# ('$7,000,000', 'NNS')
# ('$7,082', 'NNS')
# ('$7,500,000', 'NNS')
# ('$7.00', 'NNS')
# ('$7.20', 'NNS')
# ('$7.50', 'NNS')
# ('$70', 'NNS')
# ('$70,000', 'NNS')
# ('$700', 'NNS')
# ('$720', 'NNS')
# ('$73.50', 'NNS')
# ('$740', 'NNS')
# ('$740,000', 'NNS')
# ('$75', 'NNS')
# ('$75,000,000', 'NNS')
# ('$75-billion', 'NNS')
# ('$750', 'NNS')
# ('$750,000', 'NNS')
# ('$754', 'NNS')
# ('$77,389,000', 'NNS')
# ('$79.89', 'NNS')
# ('$8', 'NNS')
# ('$8,250', 'NNS')
# ('$8,313,514', 'NNS')
# ('$8,555', 'NNS')
# ('$8.00', 'NNS')
# ('$8.5', 'NNS')
# ('$8.50', 'NNS')
# ('$80', 'NNS')
# ('$80,738', 'NNS')
# ('$800', 'NNS')
# ('$800,000', 'NNS')
# ('$81', 'NNS')
# ('$83,750', 'NNS')
# ('$84,000,000', 'NNS')
# ('$840,000', 'NNS')
# ('$842,617', 'NNS')
# ('$85', 'NNS')
# ('$85,000', 'NNS')
# ('$88,000', 'NNS')
# ('$9', 'NNS')
# ('$9,841,000', 'NNS')
# ('$9.2', 'NNS')
# ('$9.50', 'NNS')
# ('$90', 'NNS')
# ('$900', 'NNS')
# ('$94', 'NNS')
# ("'20's", 'NNS')
# ("'20s", 'NNS')
# ("'30s", 'NNS')
# ("'40's", 'NNS')
# ("'50's", 'NNS')
# ("'60s", 'NNS')
# ("'80's", 'NNS')
# ("'90s", 'NNS')
# ("'thirties", 'NNS')
# ('-16-degrees', 'NNS')
# ('-20-degrees', 'NNS')
# ('-20-degrees-c', 'NNS')
# ('-78-degrees', 'NNS')
# ('0.3m', 'NNS')
# ("0.5''", 'NNS')
# ("10''", 'NNS')
# ('10-degrees', 'NNS')
# ('10-degrees-c', 'NNS')
# ('105-degrees', 'NNS')
# ('105-degrees-f', 'NNS')
# ('109-degrees-f', 'NNS')
# ('110-degrees', 'NNS')
# ('110-degrees-c', 'NNS')
# ("12'", 'NNS')
# ("12''", 'NNS')
# ('120-degrees', 'NNS')
# ('140-degrees-f', 'NNS')
# ('160-degrees-f', 'NNS')
# ('170-degrees-c', 'NNS')
# ("1700's", 'NNS')
# ("1770's", 'NNS')
# ("18'.5", 'NNS')
# ('180-degrees', 'NNS')
# ("1800's", 'NNS')
# ("1840's", 'NNS')
# ("1850's", 'NNS')
# ("1860's", 'NNS')
# ("1870's", 'NNS')
# ('1880s', 'NNS')
# ("1890's", 'NNS')
# ('1890s', 'NNS')
# ("1900's", 'NNS')
# ("1920's", 'NNS')
# ('1920s', 'NNS')
# ("1930's", 'NNS')
# ('1930s', 'NNS')
# ("1940's", 'NNS')
# ('1940s', 'NNS')
# ("1950's", 'NNS')
# ('1950s', 'NNS')
# ("1960's", 'NNS')
# ('1960s', 'NNS')
# ('1970s', 'NNS')
# ("2'", 'NNS')
# ("2-3/4''", 'NNS')
# ('2-degrees-c', 'NNS')
# ('2-year-olds', 'NNS')
# ('20-degrees-c', 'NNS')
# ('200-degrees', 'NNS')
# ("21/64''", 'NNS')
# ('220-degrees', 'NNS')
# ("24''", 'NNS')
# ('24-degrees', 'NNS')
# ('25-cents', 'NNS')
# ('275-degrees-f', 'NNS')
# ('294-degrees-k', 'NNS')
# ("3-1/2''", 'NNS')
# ("3-3/4''", 'NNS')
# ("3.25''", 'NNS')
# ("30''", 'NNS')
# ('32-degrees-f', 'NNS')
# ('325-degrees-c', 'NNS')
# ('337-degrees-c', 'NNS')
# ('340-degrees-c', 'NNS')
# ('37-degrees', 'NNS')
# ('37-degrees-c', 'NNS')
# ('375-degrees-c', 'NNS')
# ("4'", 'NNS')
# ('40-degrees-f', 'NNS')
# ('410-degrees-c', 'NNS')
# ('42-degrees-f.', 'NNS')
# ('45-degrees', 'NNS')
# ('463-degrees-c', 'NNS')
# ('470-degrees-c', 'NNS')
# ("48''", 'NNS')
# ("5-3/4''", 'NNS')
# ('5-degrees-c', 'NNS')
# ('50-degrees', 'NNS')
# ('59-cents', 'NNS')
# ('6-degrees-c', 'NNS')
# ("60's", 'NNS')
# ('600-degrees', 'NNS')
# ('65-degrees', 'NNS')
# ("7''", 'NNS')
# ("70's", 'NNS')
# ('79-cents', 'NNS')
# ('8-balls', 'NNS')
# ("80's", 'NNS')
# ('80-degrees-c', 'NNS')
# ('85-degrees', 'NNS')
# ("9'", 'NNS')
# ('90-degrees', 'NNS')
# ('90-degrees-f', 'NNS')
# ('a.', 'NNS')
# ('a5', 'NNS')
# ('abberations', 'NNS')
# ('abbreviations', 'NNS')
# ('aberrations', 'NNS')
# ('abides', 'VBZ')
# ('abilities', 'NNS')
# ('abnormalities', 'NNS')
# ('abolitionists', 'NNS')
# ('aborigines', 'NNS')
# ('abortions', 'NNS')
# ('abounds', 'VBZ')
# ('abscesses', 'NNS')
# ('absences', 'NNS')
# ('absolutes', 'NNS')
# ('absorbs', 'VBZ')
# ('absorptions', 'NNS')
# ('abstractionists', 'NNS')
# ('abstractions', 'NNS')
# ('abstractors', 'NNS')
# ('abstracts', 'NNS')
# ('abstrusenesses', 'NNS')
# ('absurdities', 'NNS')
# ('abuses', 'NNS')
# ('abutments', 'NNS')
# ('academics', 'NNS')
# ('academies', 'NNS')
# ('accelerations', 'NNS')
# ('accelerators', 'NNS')
# ('accelerometers', 'NNS')
# ('accents', 'NNS')
# ('accentuates', 'VBZ')
# ('accepts', 'VBZ')
# ('accesses', 'NNS')
# ('accessions', 'NNS')
# ('accessories', 'NNS')
# ('accidents', 'NNS')
# ('acclaims', 'VBZ')
# ('accolades', 'NNS')
# ('accommodates', 'VBZ')
# ('accommodations', 'NNS')
# ('accomodations', 'NNS')
# ('accompanies', 'VBZ')
# ('accompaniments', 'NNS')
# ('accompanists', 'NNS')
# ('accomplices', 'NNS')
# ('accomplishes', 'VBZ')
# ('accomplishments', 'NNS')
# ('accords', 'VBZ')
# ('accountants', 'NNS')
# ('accounts', 'NNS')
# ('accounts', 'VBZ')
# ('accouterments', 'NNS')
# ('accretions', 'NNS')
# ('accrues', 'VBZ')
# ('accumulates', 'VBZ')
# ('accusations', 'NNS')
# ('accuses', 'VBZ')
# ('aces', 'NNS')
# ('aches', 'VBZ')
# ('achievements', 'NNS')
# ('achieves', 'VBZ')
# ('acids', 'NNS')
# ('acknowledges', 'VBZ')
# ('acknowledgments', 'NNS')
# ('acorns', 'NNS')
# ('acoustics', 'NNS')
# ('acquires', 'VBZ')
# ('acquisitions', 'NNS')
# ('acre-feet', 'NNS')
# ('acres', 'NNS')
# ('acrobats', 'NNS')
# ('actions', 'NNS')
# ('actives', 'NNS')
# ('activities', 'NNS')
# ('actors', 'NNS')
# ('actresses', 'NNS')
# ('acts', 'NNS')
# ('acts', 'VBZ')
# ('actualities', 'NNS')
# ('adagios', 'NNS')
# ('adaptations', 'NNS')
# ('adapters', 'NNS')
# ('addicts', 'NNS')
# ('additions', 'NNS')
# ('additives', 'NNS')
# ('addressees', 'NNS')
# ('addresses', 'NNS')
# ('addresses', 'VBZ')
# ('adds', 'VBZ')
# ('adenomas', 'NNS')
# ('adherents', 'NNS')
# ('adheres', 'VBZ')
# ('adhesives', 'NNS')
# ('adjectives', 'NNS')
# ('adjoins', 'VBZ')
# ('adjourns', 'VBZ')
# ('adjuncts', 'NNS')
# ('adjustments', 'NNS')
# ('adjusts', 'VBZ')
# ('administers', 'VBZ')
# ('administrators', 'NNS')
# ('admirals', 'NNS')
# ('admirers', 'NNS')
# ('admires', 'VBZ')
# ('admissions', 'NNS')
# ('admits', 'VBZ')
# ('admonishments', 'NNS')
# ('admonitions', 'NNS')
# ('adolescents', 'NNS')
# ('adopts', 'VBZ')
# ('adores', 'VBZ')
# ('adorns', 'VBZ')
# ('ads', 'NNS')
# ('adsorbs', 'VBZ')
# ('adulterers', 'NNS')
# ('adults', 'NNS')
# ('advancements', 'NNS')
# ('advances', 'NNS')
# ('advances', 'VBZ')
# ('advantages', 'NNS')
# ('adventurers', 'NNS')
# ('adventures', 'NNS')
# ('adverbs', 'NNS')
# ('adversaries', 'NNS')
# ('advertisements', 'NNS')
# ('advertisers', 'NNS')
# ('advertises', 'VBZ')
# ('advisers', 'NNS')
# ('advises', 'VBZ')
# ('advisors', 'NNS')
# ('advocates', 'NNS')
# ('aerates', 'VBZ')
# ('aerials', 'NNS')
# ('aerosols', 'NNS')
# ('aesthetes', 'NNS')
# ('af-values', 'NNS')
# ('affairs', 'NNS')
# ('affections', 'NNS')
# ('affects', 'NNS')
# ('affects', 'VBZ')
# ('affidavits', 'NNS')
# ('affiliates', 'NNS')
# ('affiliations', 'NNS')
# ('affinities', 'NNS')
# ('affirmations', 'NNS')
# ('affirms', 'VBZ')
# ('afflictions', 'NNS')
# ('affords', 'VBZ')
# ('after-effects', 'NNS')
# ('afternoons', 'NNS')
# ('agates', 'NNS')
# ('agencies', 'NNS')
# ('agenda', 'NNS')
# ('agents', 'NNS')
# ('ages', 'NNS')
# ('agglutinins', 'NNS')
# ('aggravates', 'VBZ')
# ('aggregations', 'NNS')
# ('aggressions', 'NNS')
# ('agitators', 'NNS')
# ('agnostics', 'NNS')
# ('agonies', 'NNS')
# ('agonizes', 'VBZ')
# ('agreements', 'NNS')
# ('agrees', 'VBZ')
# ('aides', 'NNS')
# ('aids', 'NNS')
# ('aids', 'VBZ')
# ('ailerons', 'NNS')
# ('ailments', 'NNS')
# ('aims', 'NNS')
# ('aims', 'VBZ')
# ('air-drifts', 'NNS')
# ('aircraft', 'NNS')
# ('airdrops', 'NNS')
# ('airfields', 'NNS')
# ('airlines', 'NNS')
# ('airmen', 'NNS')
# ('airplanes', 'NNS')
# ('airports', 'NNS')
# ('airs', 'NNS')
# ('airstrips', 'NNS')
# ('airways', 'NNS')
# ('alarms', 'NNS')
# ('albums', 'NNS')
# ('alcoholics', 'NNS')
# ('alcohols', 'NNS')
# ('alcoves', 'NNS')
# ('aldermen', 'NNS')
# ('alerts', 'VBZ')
# ('algae', 'NNS')
# ('alginates', 'NNS')
# ('alibis', 'NNS')
# ('alienates', 'VBZ')
# ('aliens', 'NNS')
# ('alignments', 'NNS')
# ('aliquots', 'NNS')
# ('alkalis', 'NNS')
# ('alkaloids', 'NNS')
# ('alkylbenzenesulfonates', 'NNS')
# ('allegations', 'NNS')
# ('allegiances', 'NNS')
# ('allergies', 'NNS')
# ('alleys', 'NNS')
# ('alleyways', 'NNS')
# ('alliances', 'NNS')
# ('allies', 'NNS')
# ('allocations', 'NNS')
# ('allotments', 'NNS')
# ('allowances', 'NNS')
# ('allows', 'VBZ')
# ('alloys', 'NNS')
# ('alludes', 'VBZ')
# ('allusions', 'NNS')
# ('almonds', 'NNS')
# ('alter-parents', 'NNS')
# ('alterations', 'NNS')
# ('alternatives', 'NNS')
# ('alters', 'VBZ')
# ('alumnae', 'NNS')
# ('alumni', 'NNS')
# ('alveoli', 'NNS')
# ('amateurs', 'NNS')
# ('amazons', 'NNS')
# ('ambassadors', 'NNS')
# ('ambiguities', 'NNS')
# ('ambitions', 'NNS')
# ('ambulances', 'NNS')
# ('ambushes', 'NNS')
# ('amendments', 'NNS')
# ('amines', 'NNS')
# ('amounts', 'NNS')
# ('amounts', 'VBZ')
# ('amphetamines', 'NNS')
# ('amplifiers', 'NNS')
# ('amulets', 'NNS')
# ('amusements', 'NNS')
# ('anachronisms', 'NNS')
# ('anacondas', 'NNS')
# ('analogies', 'NNS')
# ('analogues', 'NNS')
# ('analyses', 'NNS')
# ('analysts', 'NNS')
# ('analyzes', 'VBZ')
# ('anarchist-adventurers', 'NNS')
# ('anastomoses', 'NNS')
# ('anatomicals', 'NNS')
# ('ancestors', 'NNS')
# ('anchors', 'NNS')
# ('ancients', 'NNS')
# ('andrenas', 'NNS')
# ('anecdotes', 'NNS')
# ('anesthetics', 'NNS')
# ('angels', 'NNS')
# ('angles', 'NNS')
# ('animals', 'NNS')
# ('anionics', 'NNS')
# ('anions', 'NNS')
# ('ankles', 'NNS')
# ('annals', 'NNS')
# ('anniversaries', 'NNS')
# ('announcements', 'NNS')
# ('announcers', 'NNS')
# ('announces', 'VBZ')
# ('annoyances', 'NNS')
# ('annoys', 'VBZ')
# ('anodes', 'NNS')
# ('anomalies', 'NNS')
# ('answers', 'NNS')
# ('answers', 'VBZ')
# ('antagonisms', 'NNS')
# ('antagonists', 'NNS')
# ('antecedents', 'NNS')
# ('antennae', 'NNS')
# ('antennas', 'NNS')
# ('anteriors', 'NNS')
# ('anthems', 'NNS')
# ('anthropologists', 'NNS')
# ('anti-communists', 'NNS')
# ('anti-semites', 'NNS')
# ('antibiotics', 'NNS')
# ('antibodies', 'NNS')
# ('anticipates', 'VBZ')
# ('anticipations', 'NNS')
# ('antics', 'NNS')
# ('antipodes', 'NNS')
# ('antiquarians', 'NNS')
# ('antiques', 'NNS')
# ('antiquities', 'NNS')
# ('antisera', 'NNS')
# ('ants', 'NNS')
# ('anxieties', 'NNS')
# ('apartments', 'NNS')
# ('apologies', 'NNS')
# ('apostates', 'NNS')
# ('apostles', 'NNS')
# ('appeals', 'NNS')
# ('appeals', 'VBZ')
# ('appearances', 'NNS')
# ('appears', 'VBZ')
# ('appendages', 'NNS')
# ('appetites', 'NNS')
# ('apples', 'NNS')
# ('appliances', 'NNS')
# ('applicants', 'NNS')
# ('applications', 'NNS')
# ('applies', 'VBZ')
# ('appliques', 'NNS')
# ('appointees', 'NNS')
# ('appointments', 'NNS')
# ('appoints', 'VBZ')
# ('apportionments', 'NNS')
# ('appraisals', 'NNS')
# ('appraisers', 'NNS')
# ('appreciates', 'VBZ')
# ('appreciations', 'NNS')
# ('apprehensions', 'NNS')
# ('apprentices', 'NNS')
# ('approaches', 'NNS')
# ('approaches', 'VBZ')
# ('appropriates', 'VBZ')
# ('appropriations', 'NNS')
# ('approves', 'VBZ')
# ('approximations', 'NNS')
# ('aprons', 'NNS')
# ('apses', 'NNS')
# ('aptitudes', 'NNS')
# ('aqueducts', 'NNS')
# ('arcades', 'NNS')
# ('archaeologists', 'NNS')
# ('archangels', 'NNS')
# ('arches', 'NNS')
# ('arches', 'VBZ')
# ('architects', 'NNS')
# ('architectures', 'NNS')
# ('archives', 'NNS')
# ('arcs', 'NNS')
# ('areas', 'NNS')
# ('areaways', 'NNS')
# ('arenas', 'NNS')
# ('argues', 'VBZ')
# ('arguments', 'NNS')
# ('arises', 'VBZ')
# ('aristocrats', 'NNS')
# ('armaments', 'NNS')
# ('armchairs', 'NNS')
# ('armies', 'NNS')
# ('armpits', 'NNS')
# ('arms', 'NNS')
# ('aromas', 'NNS')
# ('arouses', 'VBZ')
# ('arpeggios', 'NNS')
# ('arrangements', 'NNS')
# ('arrangers', 'NNS')
# ('arranges', 'VBZ')
# ('arrears', 'NNS')
# ('arrests', 'NNS')
# ('arrivals', 'NNS')
# ('arrives', 'VBZ')
# ('arrowheads', 'NNS')
# ('arrows', 'NNS')
# ('arsines', 'NNS')
# ('arteries', 'NNS')
# ('arterioles', 'NNS')
# ('articles', 'NNS')
# ('articulations', 'NNS')
# ('artifacts', 'NNS')
# ('artisans', 'NNS')
# ('artists', 'NNS')
# ('arts', 'NNS')
# ('arylesterases', 'NNS')
# ('ascribes', 'VBZ')
# ('ashes', 'NNS')
# ('ashtrays', 'NNS')
# ('asks', 'VBZ')
# ('aspects', 'NNS')
# ('aspirants', 'NNS')
# ('aspirations', 'NNS')
# ('aspires', 'VBZ')
# ('assailants', 'NNS')
# ('assassins', 'NNS')
# ('assaults', 'NNS')
# ('assaults', 'VBZ')
# ('assemblages', 'NNS')
# ('assemblies', 'NNS')
# ('assertions', 'NNS')
# ('asserts', 'VBZ')
# ('asses', 'NNS')
# ('assessments', 'NNS')
# ('assessors', 'NNS')
# ('assets', 'NNS')
# ('assignments', 'NNS')
# ('assigns', 'VBZ')
# ('assistants', 'NNS')
# ('assists', 'NNS')
# ('associates', 'NNS')
# ('associates', 'VBZ')
# ('associations', 'NNS')
# ('assumes', 'VBZ')
# ('assumptions', 'NNS')
# ('assurances', 'NNS')
# ('assures', 'VBZ')
# ('asterisks', 'NNS')
# ('asters', 'NNS')
# ('at-bats', 'NNS')
# ('atheists', 'NNS')
# ('athletes', 'NNS')
# ('athletics', 'NNS')
# ('atmospheres', 'NNS')
# ('atoms', 'NNS')
# ('atrocities', 'NNS')
# ('attaches', 'VBZ')
# ('attachments', 'NNS')
# ('attackers', 'NNS')
# ('attacks', 'NNS')
# ('attacks', 'VBZ')
# ('attainments', 'NNS')
# ('attains', 'VBZ')
# ('attempts', 'NNS')
# ('attempts', 'VBZ')
# ('attendants', 'NNS')
# ('attends', 'VBZ')
# ('attentions', 'NNS')
# ('attitudes', 'NNS')
# ('attorneys', 'NNS')
# ('attractions', 'NNS')
# ('attracts', 'VBZ')
# ('attributes', 'NNS')
# ('attributes', 'VBZ')
# ('audiences', 'NNS')
# ('auditions', 'NNS')
# ('auditors', 'NNS')
# ('augurs', 'VBZ')
# ('aunts', 'NNS')
# ('auspices', 'NNS')
# ('australites', 'NNS')
# ('authentications', 'NNS')
# ('authorities', 'NNS')
# ('authorizations', 'NNS')
# ('authorizes', 'VBZ')
# ('authors', 'NNS')
# ('auto-loaders', 'NNS')
# ('autocracies', 'NNS')
# ('autocrats', 'NNS')
# ('automobiles', 'NNS')
# ('autos', 'NNS')
# ('auxiliaries', 'NNS')
# ('availabilities', 'NNS')
# ('avenues', 'NNS')
# ('averages', 'NNS')
# ('aviators', 'NNS')
# ('avocados', 'NNS')
# ('avoids', 'VBZ')
# ('awaits', 'VBZ')
# ('awakens', 'VBZ')
# ('awards', 'NNS')
# ('awnings', 'NNS')
# ('axes', 'NNS')
# ('axioms', 'NNS')
# ('axles', 'NNS')
# ('ayes', 'NNS')
# ('azaleas', 'NNS')
# ('babes', 'NNS')
# ('babies', 'NNS')
# ('bachelors', 'NNS')
# ('backbends', 'NNS')
# ('backers', 'NNS')
# ('backgrounds', 'NNS')
# ('backs', 'NNS')
# ('backs', 'VBZ')
# ('backwoods', 'NNS')
# ('backyards', 'NNS')
# ('bacteria', 'NNS')
# ('badges', 'NNS')
# ('badmen', 'NNS')
# ('bads', 'NNS')
# ('bags', 'NNS')
# ('bake-offs', 'NNS')
# ('bakes', 'VBZ')
# ('balances', 'NNS')
# ('balconies', 'NNS')
# ('bales', 'NNS')
# ('balks', 'VBZ')
# ('ball-carriers', 'NNS')
# ('ballads', 'NNS')
# ('ballards', 'NNS')
# ('ballerinas', 'NNS')
# ('ballets', 'NNS')
# ('ballfields', 'NNS')
# ('ballgowns', 'NNS')
# ('ballistics', 'NNS')
# ('balloons', 'NNS')
# ('ballots', 'NNS')
# ('ballplayers', 'NNS')
# ('balls', 'NNS')
# ('balsams', 'NNS')
# ('bananas', 'NNS')
# ('bandages', 'NNS')
# ('bandits', 'NNS')
# ('bandoleers', 'NNS')
# ('bands', 'NNS')
# ('bang-sashes', 'NNS')
# ('bangs', 'NNS')
# ('bangs', 'VBZ')
# ('banishes', 'VBZ')
# ('banisters', 'NNS')
# ('bankers', 'NNS')
# ('banks', 'NNS')
# ('banks', 'VBZ')
# ('banners', 'NNS')
# ('banquetings', 'NNS')
# ('banquets', 'NNS')
# ('bans', 'VBZ')
# ('banshees', 'NNS')
# ('baptisms', 'NNS')
# ('barbarians', 'NNS')
# ('barbecues', 'NNS')
# ('barbs', 'NNS')
# ('bards', 'NNS')
# ('barflies', 'NNS')
# ('bargains', 'NNS')
# ('bargains', 'VBZ')
# ('barges', 'NNS')
# ('barns', 'NNS')
# ('barnsful', 'NNS')
# ('barnyards', 'NNS')
# ('barons', 'NNS')
# ('barracks', 'NNS')
# ('barrels', 'NNS')
# ('barricades', 'NNS')
# ('barriers', 'NNS')
# ('bars', 'NNS')
# ('bars', 'VBZ')
# ('bas-reliefs', 'NNS')
# ('baseballs', 'NNS')
# ('basements', 'NNS')
# ('bases', 'NNS')
# ('bases', 'VBZ')
# ('basics', 'NNS')
# ('baskets', 'NNS')
# ('basses', 'NNS')
# ('bastards', 'NNS')
# ('bathers', 'NNS')
# ('bathrooms', 'NNS')
# ('baths', 'NNS')
# ('bathtubs', 'NNS')
# ('bats', 'NNS')
# ('bats', 'VBZ')
# ('battalions', 'NNS')
# ('battens', 'NNS')
# ('batteries', 'NNS')
# ('batters', 'NNS')
# ('battlefields', 'NNS')
# ('battlements', 'NNS')
# ('battles', 'NNS')
# ('batwings', 'NNS')
# ('bawhs', 'NNS')
# ('bayonets', 'NNS')
# ('bays', 'NNS')
# ('bazaars', 'NNS')
# ('beaches', 'NNS')
# ('beads', 'NNS')
# ('beakers', 'NNS')
# ('beams', 'NNS')
# ('beans', 'NNS')
# ('bear', 'NNS')
# ('beards', 'NNS')
# ('bearings', 'NNS')
# ('bears', 'VBZ')
# ('beasties', 'NNS')
# ('beasts', 'NNS')
# ('beat', 'NNS')
# ('beatings', 'NNS')
# ('beatniks', 'NNS')
# ('beats', 'NNS')
# ('beats', 'VBZ')
# ('beauties', 'NNS')
# ('beckons', 'VBZ')
# ('becomes', 'VBZ')
# ('becometh', 'VBZ')
# ('bedbugs', 'NNS')
# ('bedrooms', 'NNS')
# ('beds', 'NNS')
# ('bedsprings', 'NNS')
# ('beeps', 'NNS')
# ('beer-runners', 'NNS')
# ('beers', 'NNS')
# ('bees', 'NNS')
# ('beetles', 'NNS')
# ('beets', 'NNS')
# ('befits', 'VBZ')
# ('befuddles', 'VBZ')
# ('beggars', 'NNS')
# ('beginners', 'NNS')
# ('beginnings', 'NNS')
# ('begins', 'VBZ')
# ('begs', 'VBZ')
# ('behaves', 'VBZ')
# ('behaviors', 'NNS')
# ('beholds', 'VBZ')
# ('behooves', 'VBZ')
# ('beings', 'NNS')
# ('beliefs', 'NNS')
# ('believers', 'NNS')
# ('believes', 'VBZ')
# ('believeth', 'VBZ')
# ('bellboys', 'NNS')
# ('belles', 'NNS')
# ('bellhops', 'NNS')
# ('bellies', 'NNS')
# ('bellows', 'NNS')
# ('bellows', 'VBZ')
# ('bells', 'NNS')
# ('bellwethers', 'NNS')
# ('belongings', 'NNS')
# ('belongs', 'VBZ')
# ('belts', 'NNS')
# ('belts', 'VBZ')
# ('bemoans', 'VBZ')
# ('benches', 'NNS')
# ('benchmarks', 'NNS')
# ('bends', 'NNS')
# ('bends', 'VBZ')
# ('beneficiaries', 'NNS')
# ('benefits', 'NNS')
# ('benefits', 'VBZ')
# ('bequests', 'NNS')
# ('bereavements', 'NNS')
# ('bergs', 'NNS')
# ('berries', 'NNS')
# ('besets', 'VBZ')
# ('besiegers', 'NNS')
# ('bespeaks', 'VBZ')
# ('best-sellers', 'NNS')
# ('bestes', 'NNS')
# ('betrays', 'VBZ')
# ('bets', 'NNS')
# ('betties', 'NNS')
# ('bevels', 'NNS')
# ('beverages', 'NNS')
# ('bewilders', 'VBZ')
# ('biases', 'NNS')
# ('bibles', 'NNS')
# ('bibliographies', 'NNS')
# ('bibliophiles', 'NNS')
# ('biches', 'NNS')
# ('bicycles', 'NNS')
# ('bidders', 'NNS')
# ('biddies', 'NNS')
# ('bids', 'NNS')
# ('bifocals', 'NNS')
# ('bigots', 'NNS')
# ('bikinis', 'NNS')
# ('billboards', 'NNS')
# ('billets', 'NNS')
# ('billions', 'NNS')
# ('billows', 'NNS')
# ('bills', 'NNS')
# ('binders', 'NNS')
# ('binds', 'VBZ')
# ('binoculars', 'NNS')
# ('bins', 'NNS')
# ('biographers', 'NNS')
# ('biologists', 'NNS')
# ('biopsies', 'NNS')
# ('birches', 'NNS')
# ('birdies', 'NNS')
# ('birds', 'NNS')
# ('births', 'NNS')
# ('biscuits', 'NNS')
# ('bishops', 'NNS')
# ('bites', 'NNS')
# ('bites', 'VBZ')
# ('bits', 'NNS')
# ('bitters', 'NNS')
# ('blackbirds', 'NNS')
# ('blacks', 'NNS')
# ('blades', 'NNS')
# ('blankets', 'NNS')
# ('blankets', 'VBZ')
# ('blanks', 'NNS')
# ('blasphemies', 'NNS')
# ('blasts', 'NNS')
# ('bleachers', 'NNS')
# ('bleats', 'NNS')
# ('blebs', 'NNS')
# ('bleedings', 'NNS')
# ('bleeps', 'NNS')
# ('blemishes', 'NNS')
# ('blends', 'NNS')
# ('blessings', 'NNS')
# ('blinds', 'NNS')
# ('blinkers', 'NNS')
# ('blips', 'NNS')
# ('blisters', 'NNS')
# ('blitzes', 'NNS')
# ('blizzards', 'NNS')
# ('blockages', 'NNS')
# ('blocks', 'NNS')
# ('blokes', 'NNS')
# ('blondes', 'NNS')
# ('bloodhounds', 'NNS')
# ('bloods', 'NNS')
# ('bloodspots', 'NNS')
# ('bloodstains', 'NNS')
# ('blooms', 'NNS')
# ('bloops', 'NNS')
# ('blossoms', 'NNS')
# ('blots', 'NNS')
# ('blots', 'VBZ')
# ('blouses', 'NNS')
# ('blowers', 'NNS')
# ('blowfish', 'NNS')
# ('blows', 'NNS')
# ('blows', 'VBZ')
# ('blue-eyes', 'NNS')
# ('blueberries', 'NNS')
# ('bluebonnets', 'NNS')
# ('bluefish', 'NNS')
# ('blueprints', 'NNS')
# ('blueprints', 'VBZ')
# ('blues', 'NNS')
# ('bluffs', 'NNS')
# ('blunderings', 'NNS')
# ('blunders', 'NNS')
# ('blunts', 'VBZ')
# ('blushes', 'NNS')
# ('boardinghouses', 'NNS')
# ('boards', 'NNS')
# ('boards', 'VBZ')
# ('boastings', 'NNS')
# ('boasts', 'VBZ')
# ('boatels', 'NNS')
# ('boaters', 'NNS')
# ('boathouses', 'NNS')
# ('boatloads', 'NNS')
# ('boatmen', 'NNS')
# ('boats', 'NNS')
# ('boatsmen', 'NNS')
# ('boatyards', 'NNS')
# ('bobbins', 'NNS')
# ('bobby-sox', 'NNS')
# ('bodes', 'VBZ')
# ('bodies', 'NNS')
# ('bodies', 'VBZ')
# ('bodybuilders', 'NNS')
# ('bogeymen', 'NNS')
# ('bogeys', 'NNS')
# ('bogies', 'NNS')
# ('boies', 'NNS')
# ('boilers', 'NNS')
# ('boils', 'NNS')
# ('boils', 'VBZ')
# ('bolts', 'NNS')
# ('bombers', 'NNS')
# ('bombings', 'NNS')
# ('bombs', 'NNS')
# ('bonds', 'NNS')
# ('bones', 'NNS')
# ('bonfires', 'NNS')
# ('bonzes', 'NNS')
# ('bookcases', 'NNS')
# ('bookers', 'NNS')
# ('bookies', 'NNS')
# ('bookings', 'NNS')
# ('booklets', 'NNS')
# ('booklists', 'NNS')
# ('books', 'NNS')
# ('bookshelves', 'NNS')
# ('boomerangs', 'VBZ')
# ('boors', 'NNS')
# ('boos', 'NNS')
# ('boosts', 'NNS')
# ('booths', 'NNS')
# ('bootleggers', 'NNS')
# ('boots', 'NNS')
# ('borates', 'NNS')
# ('borderlands', 'NNS')
# ('borders', 'NNS')
# ('borders', 'VBZ')
# ('bores', 'NNS')
# ('bores', 'VBZ')
# ('boroughs', 'NNS')
# ('borrows', 'VBZ')
# ('bosoms', 'NNS')
# ('bosses', 'NNS')
# ('botanists', 'NNS')
# ('bothers', 'VBZ')
# ('bottlenecks', 'NNS')
# ('bottles', 'NNS')
# ('bottles', 'VBZ')
# ('bottoms', 'NNS')
# ('boughs', 'NNS')
# ('boulders', 'NNS')
# ('boulevards', 'NNS')
# ('boundaries', 'NNS')
# ('bounds', 'NNS')
# ('bouquets', 'NNS')
# ('bouts', 'NNS')
# ('bovines', 'NNS')
# ('bowels', 'NNS')
# ('bowls', 'NNS')
# ('bows', 'NNS')
# ('bows', 'VBZ')
# ('boxcars', 'NNS')
# ('boxes', 'NNS')
# ('boyars', 'NNS')
# ('boys', 'NNS')
# ('braces', 'NNS')
# ('brackets', 'NNS')
# ('braids', 'NNS')
# ('brains', 'NNS')
# ('brakes', 'NNS')
# ('brambles', 'NNS')
# ('branches', 'NNS')
# ('brands', 'NNS')
# ('breakables', 'NNS')
# ('breakdowns', 'NNS')
# ('breakers', 'NNS')
# ('breakfasts', 'NNS')
# ('breaks', 'NNS')
# ('breaks', 'VBZ')
# ('breakthroughs', 'NNS')
# ('breakups', 'NNS')
# ('breakwaters', 'NNS')
# ('breasts', 'NNS')
# ('breastworks', 'NNS')
# ('breathes', 'VBZ')
# ('breaths', 'NNS')
# ('breeches', 'NNS')
# ('breeds', 'NNS')
# ('breezes', 'NNS')
# ('brethren', 'NNS')
# ('brewers', 'NNS')
# ('bribers', 'NNS')
# ('bribes', 'NNS')
# ('bricklayers', 'NNS')
# ('bricks', 'NNS')
# ('brides', 'NNS')
# ('bridesmaids', 'NNS')
# ('bridges', 'NNS')
# ('bridges', 'VBZ')
# ('briefs', 'NNS')
# ('brigades', 'NNS')
# ('brightens', 'VBZ')
# ('brings', 'VBZ')
# ('bristles', 'NNS')
# ('bristles', 'VBZ')
# ('broadcastings', 'NNS')
# ('broadcasts', 'NNS')
# ('broadens', 'VBZ')
# ('brochures', 'NNS')
# ('brokers', 'NNS')
# ('bromides', 'NNS')
# ('bronchi', 'NNS')
# ('bronchioles', 'NNS')
# ('broncs', 'NNS')
# ('broods', 'NNS')
# ('brothels', 'NNS')
# ('brothers', 'NNS')
# ('brows', 'NNS')
# ('bruises', 'NNS')
# ('brunches', 'NNS')
# ('brunettes', 'NNS')
# ('brushes', 'NNS')
# ('brutalities', 'NNS')
# ('bubbles', 'NNS')
# ('bubbles', 'VBZ')
# ('buckaroos', 'NNS')
# ('buckets', 'NNS')
# ('buckles', 'NNS')
# ('bucks', 'NNS')
# ('buckskins', 'NNS')
# ('buddies', 'NNS')
# ('budgets', 'NNS')
# ('buds', 'NNS')
# ('buffalo', 'NNS')
# ('buffaloes', 'NNS')
# ('buffetings', 'NNS')
# ('buffets', 'NNS')
# ('buffoons', 'NNS')
# ('buffs', 'NNS')
# ('buggers', 'NNS')
# ('buggies', 'NNS')
# ('bugs', 'NNS')
# ('bugs', 'VBZ')
# ('builders', 'NNS')
# ('buildings', 'NNS')
# ('builds', 'VBZ')
# ('bulbs', 'NNS')
# ('bulkheads', 'NNS')
# ('bulks', 'VBZ')
# ("bull's-eyes", 'NNS')
# ('bull-sessions', 'NNS')
# ('bulletins', 'NNS')
# ('bulletins', 'VBZ')
# ('bullets', 'NNS')
# ('bullies', 'NNS')
# ('bullies', 'VBZ')
# ('bulls', 'NNS')
# ('bullwhackers', 'NNS')
# ('bullyboys', 'NNS')
# ('bumblebees', 'NNS')
# ('bumpers', 'NNS')
# ('bumps', 'NNS')
# ('bums', 'NNS')
# ('bundles', 'NNS')
# ('bunkmates', 'NNS')
# ('bunks', 'NNS')
# ('buns', 'NNS')
# ('bunters', 'NNS')
# ('buoys', 'NNS')
# ('burdens', 'NNS')
# ('bureaucracies', 'NNS')
# ('bureaucrats', 'NNS')
# ('bureaus', 'NNS')
# ('burgesses', 'NNS')
# ('burglars', 'NNS')
# ('buries', 'VBZ')
# ('burlesques', 'NNS')
# ('burners', 'NNS')
# ('burnings', 'NNS')
# ('burns', 'NNS')
# ('burns', 'VBZ')
# ('burrows', 'NNS')
# ('burrs', 'NNS')
# ('bursts', 'NNS')
# ('buses', 'NNS')
# ('bushels', 'NNS')
# ('bushes', 'NNS')
# ('businesses', 'NNS')
# ('businessmen', 'NNS')
# ('busses', 'NNS')
# ('busts', 'NNS')
# ('butlers', 'NNS')
# ('butterflies', 'NNS')
# ('buttocks', 'NNS')
# ('buttonholes', 'NNS')
# ('buttons', 'NNS')
# ('buttresses', 'NNS')
# ('butts', 'NNS')
# ('butts', 'VBZ')
# ('buyers', 'NNS')
# ('buys', 'VBZ')
# ('buzzes', 'NNS')
# ('by-laws', 'NNS')
# ('by-passes', 'VBZ')
# ('by-products', 'NNS')
# ('by-roads', 'NNS')
# ('by-ways', 'NNS')
# ('byproducts', 'NNS')
# ('cabanas', 'NNS')
# ('cabinetmakers', 'NNS')
# ('cabinets', 'NNS')
# ('cabins', 'NNS')
# ('cables', 'NNS')
# ('cabs', 'NNS')
# ('cafes', 'NNS')
# ('cafeterias', 'NNS')
# ('cages', 'NNS')
# ('cahoots', 'NNS')
# ('cakes', 'NNS')
# ('calamities', 'NNS')
# ('calculations', 'NNS')
# ('calculators', 'NNS')
# ('calculi', 'NNS')
# ('calendars', 'NNS')
# ('calibers', 'NNS')
# ('calibrations', 'NNS')
# ('calipers', 'NNS')
# ('caliphs', 'NNS')
# ('calisthenics', 'NNS')
# ('call-backs', 'NNS')
# ('callers', 'NNS')
# ('calligraphers', 'NNS')
# ('calls', 'NNS')
# ('calls', 'VBZ')
# ('calluses', 'NNS')
# ('calories', 'NNS')
# ('calves', 'NNS')
# ('camellias', 'NNS')
# ('camels', 'NNS')
# ('cameos', 'NNS')
# ('cameramen', 'NNS')
# ('cameras', 'NNS')
# ('campaigners', 'NNS')
# ('campaigns', 'NNS')
# ('campers', 'NNS')
# ('campgrounds', 'NNS')
# ('camps', 'NNS')
# ('campsites', 'NNS')
# ('campuses', 'NNS')
# ('cams', 'NNS')
# ('canals', 'NNS')
# ('cancels', 'VBZ')
# ('cancers', 'NNS')
# ('candidates', 'NNS')
# ('candies', 'NNS')
# ('candles', 'NNS')
# ('canisters', 'NNS')
# ('cannibals', 'NNS')
# ('cannon', 'NNS')
# ('canoes', 'NNS')
# ('canons', 'NNS')
# ('cans', 'NNS')
# ('cantilevers', 'NNS')
# ('cantles', 'NNS')
# ('canvases', 'NNS')
# ('canvassers', 'NNS')
# ('canyons', 'NNS')
# ('capabilities', 'NNS')
# ('capacities', 'NNS')
# ('capacitors', 'NNS')
# ('capers', 'NNS')
# ('capes', 'NNS')
# ('capita', 'NNS')
# ('capital-gains', 'NNS')
# ('capitalists', 'NNS')
# ('capitals', 'NNS')
# ('caps', 'NNS')
# ('caps', 'VBZ')
# ('capsules', 'NNS')
# ('captains', 'NNS')
# ('captions', 'NNS')
# ('captives', 'NNS')
# ('captors', 'NNS')
# ('captures', 'NNS')
# ('captures', 'VBZ')
# ('caravans', 'NNS')
# ('carbines', 'NNS')
# ('carbonates', 'NNS')
# ('carbons', 'NNS')
# ('carcasses', 'NNS')
# ('cardinals', 'NNS')
# ('cards', 'NNS')
# ('careers', 'NNS')
# ('cares', 'NNS')
# ('cares', 'VBZ')
# ('caresses', 'NNS')
# ('carloads', 'NNS')
# ('carpenters', 'NNS')
# ('carpets', 'NNS')
# ('carriages', 'NNS')
# ('carriers', 'NNS')
# ('carries', 'VBZ')
# ('carrots', 'NNS')
# ('carryovers', 'NNS')
# ('cars', 'NNS')
# ('cartels', 'NNS')
# ('cartons', 'NNS')
# ('cartoonists', 'NNS')
# ('cartoons', 'NNS')
# ('cartridges', 'NNS')
# ('carts', 'NNS')
# ('cartwheels', 'NNS')
# ('carvings', 'NNS')
# ('caryatides', 'NNS')
# ('cascades', 'VBZ')
# ('cases', 'NNS')
# ('caseworkers', 'NNS')
# ('cashews', 'NNS')
# ('caskets', 'NNS')
# ('casks', 'NNS')
# ('castanets', 'NNS')
# ('casters', 'NNS')
# ('castigates', 'VBZ')
# ('castles', 'NNS')
# ('castorbeans', 'NNS')
# ('casts', 'NNS')
# ('casts', 'VBZ')
# ('casuals', 'NNS')
# ('casualties', 'NNS')
# ('catalogs', 'NNS')
# ('catalogues', 'NNS')
# ('catalysts', 'NNS')
# ('catapults', 'VBZ')
# ('catastrophes', 'NNS')
# ('catchers', 'NNS')
# ('catches', 'NNS')
# ('catches', 'VBZ')
# ('catchwords', 'NNS')
# ('catecholamines', 'NNS')
# ('categories', 'NNS')
# ('caterpillars', 'NNS')
# ('cathedrals', 'NNS')
# ('catkins', 'NNS')
# ('cats', 'NNS')
# ('cattle', 'NNS')
# ('cattlemen', 'NNS')
# ('caucuses', 'NNS')
# ('causes', 'NNS')
# ('causes', 'VBZ')
# ('cautions', 'VBZ')
# ('cavalcades', 'NNS')
# ('cavalrymen', 'NNS')
# ('cave-men', 'NNS')
# ('cavemen', 'NNS')
# ('caves', 'NNS')
# ('cavities', 'NNS')
# ('cc.', 'NNS')
# ('ceases', 'VBZ')
# ('ceilings', 'NNS')
# ('celebrants', 'NNS')
# ('celebrates', 'VBZ')
# ('celebrations', 'NNS')
# ('celebrities', 'NNS')
# ('cellars', 'NNS')
# ('cells', 'NNS')
# ('celluloses', 'NNS')
# ('censors', 'NNS')
# ('censors', 'VBZ')
# ('censures', 'NNS')
# ('censuses', 'NNS')
# ('centers', 'NNS')
# ('centers', 'VBZ')
# ('centimeters', 'NNS')
# ('cents', 'NNS')
# ('centuries', 'NNS')
# ('cereals', 'NNS')
# ('ceremonies', 'NNS')
# ('certificates', 'NNS')
# ('certifies', 'VBZ')
# ('certitudes', 'NNS')
# ('cha-chas', 'NNS')
# ('chains', 'NNS')
# ('chairmanships', 'NNS')
# ('chairmen', 'NNS')
# ('chairs', 'NNS')
# ('challenges', 'NNS')
# ('challenges', 'VBZ')
# ('chambermaids', 'NNS')
# ('chambers', 'NNS')
# ('champions', 'NNS')
# ('champions', 'VBZ')
# ('championships', 'NNS')
# ('champs', 'NNS')
# ('chanceries', 'NNS')
# ('chances', 'NNS')
# ('chandeliers', 'NNS')
# ('changes', 'NNS')
# ('changes', 'VBZ')
# ('channels', 'NNS')
# ('chansons', 'NNS')
# ('chants', 'NNS')
# ('chapels', 'NNS')
# ('chaplains', 'NNS')
# ('chaps', 'NNS')
# ('chapters', 'NNS')
# ('characteristics', 'NNS')
# ('characterizations', 'NNS')
# ('characterizes', 'VBZ')
# ('characters', 'NNS')
# ('charges', 'NNS')
# ('charges', 'VBZ')
# ('charities', 'NNS')
# ('charlatans', 'NNS')
# ('charms', 'NNS')
# ('charters', 'NNS')
# ('chartings', 'NNS')
# ('chartists', 'NNS')
# ('charts', 'NNS')
# ('chattels', 'NNS')
# ('checks', 'NNS')
# ('checks', 'VBZ')
# ('cheekbones', 'NNS')
# ('cheeks', 'NNS')
# ('cheerleaders', 'NNS')
# ('cheers', 'NNS')
# ('chemicals', 'NNS')
# ('chemistries', 'NNS')
# ('chemists', 'NNS')
# ('cherries', 'NNS')
# ('cherubim', 'NNS')
# ('chestnuts', 'NNS')
# ('chests', 'NNS')
# ('chickens', 'NNS')
# ('chicks', 'NNS')
# ('chiefdoms', 'NNS')
# ('chiefs', 'NNS')
# ('chiggers', 'NNS')
# ('chilblains', 'NNS')
# ('children', 'NNS')
# ('chills', 'NNS')
# ('chimes', 'NNS')
# ('chimneys', 'NNS')
# ('chin-ups', 'NNS')
# ('chines', 'NNS')
# ('chins', 'NNS')
# ('chips', 'NNS')
# ('chisels', 'NNS')
# ('chives', 'NNS')
# ('chlorides', 'NNS')
# ('chocks', 'NNS')
# ('choices', 'NNS')
# ('chooses', 'VBZ')
# ('chops', 'NNS')
# ('chords', 'NNS')
# ('choreographers', 'NNS')
# ('chores', 'NNS')
# ('chorines', 'NNS')
# ('choruses', 'NNS')
# ('chowders', 'NNS')
# ('chromatics', 'NNS')
# ('chroniclers', 'NNS')
# ('chronicles', 'NNS')
# ('chrysanthemums', 'NNS')
# ('chuckles', 'NNS')
# ('chunks', 'NNS')
# ('churches', 'NNS')
# ('churchgoers', 'NNS')
# ('churchmen', 'NNS')
# ('churns', 'VBZ')
# ('cicadas', 'NNS')
# ('cigarettes', 'NNS')
# ('cigars', 'NNS')
# ('cilia', 'NNS')
# ('ciliates', 'NNS')
# ('cinches', 'NNS')
# ('cinders', 'NNS')
# ('ciphers', 'NNS')
# ('circles', 'NNS')
# ('circuits', 'NNS')
# ('circumscriptions', 'NNS')
# ('circumstances', 'NNS')
# ('citations', 'NNS')
# ('cites', 'VBZ')
# ('cities', 'NNS')
# ('citizens', 'NNS')
# ('cityscapes', 'NNS')
# ('civil-rights', 'NNS')
# ('civilians', 'NNS')
# ('civilizations', 'NNS')
# ('claimants', 'NNS')
# ('claims', 'NNS')
# ('claims', 'VBZ')
# ('clamors', 'VBZ')
# ('clamps', 'NNS')
# ('clams', 'NNS')
# ('claps', 'NNS')
# ('claps', 'VBZ')
# ('clarets', 'NNS')
# ('clarifies', 'VBZ')
# ('clashes', 'NNS')
# ('classes', 'NNS')
# ('classics', 'NNS')
# ('classifications', 'NNS')
# ('classifiers', 'NNS')
# ('classmates', 'NNS')
# ('classrooms', 'NNS')
# ('clauses', 'NNS')
# ('claws', 'NNS')
# ('clays', 'NNS')
# ('cleaners', 'NNS')
# ('cleans', 'VBZ')
# ('cleanups', 'NNS')
# ('clears', 'VBZ')
# ('clefts', 'NNS')
# ('clenches', 'VBZ')
# ('clergy', 'NNS')
# ('clergymen', 'NNS')
# ('clerks', 'NNS')
# ('cliches', 'NNS')
# ('clicks', 'NNS')
# ('clicks', 'VBZ')
# ('clients', 'NNS')
# ('cliffs', 'NNS')
# ('climates', 'NNS')
# ('climaxes', 'NNS')
# ('climbs', 'NNS')
# ('climes', 'NNS')
# ('clinches', 'NNS')
# ('clings', 'VBZ')
# ('clinics', 'NNS')
# ('clippings', 'NNS')
# ('clips', 'NNS')
# ('cliques', 'NNS')
# ('cloakrooms', 'NNS')
# ('clobbers', 'VBZ')
# ('clocks', 'NNS')
# ('clodhoppers', 'NNS')
# ('clods', 'NNS')
# ('cloisters', 'NNS')
# ('closes', 'VBZ')
# ('closets', 'NNS')
# ('closeups', 'NNS')
# ('clothes', 'NNS')
# ('clotheslines', 'NNS')
# ('clouds', 'NNS')
# ('clouds', 'VBZ')
# ('cloves', 'NNS')
# ('clowns', 'NNS')
# ('clubrooms', 'NNS')
# ('clubs', 'NNS')
# ('clucks', 'NNS')
# ('clucks', 'VBZ')
# ('clues', 'NNS')
# ('clumps', 'NNS')
# ('clusters', 'NNS')
# ('clutches', 'NNS')
# ('clutches', 'VBZ')
# ('cm.', 'NNS')
# ('co-chairmen', 'NNS')
# ('co-operates', 'VBZ')
# ('co-ops', 'NNS')
# ('co-ordinates', 'VBZ')
# ('co-signers', 'NNS')
# ('co-workers', 'NNS')
# ('coaches', 'NNS')
# ('coachmen', 'NNS')
# ('coalesces', 'VBZ')
# ('coals', 'NNS')
# ('coasts', 'NNS')
# ('coatings', 'NNS')
# ('coats', 'NNS')
# ('coattails', 'NNS')
# ('cobblestones', 'NNS')
# ('cobwebs', 'NNS')
# ('cockpits', 'NNS')
# ('cockroaches', 'NNS')
# ('cocktails', 'NNS')
# ('coconuts', 'NNS')
# ('codes', 'NNS')
# ('codetermines', 'VBZ')
# ('coeditors', 'NNS')
# ('coeds', 'NNS')
# ('coefficients', 'NNS')
# ('cofactors', 'NNS')
# ('coffers', 'NNS')
# ('cogs', 'NNS')
# ('cohorts', 'NNS')
# ('coils', 'NNS')
# ('coincidences', 'NNS')
# ('coincides', 'VBZ')
# ('coins', 'NNS')
# ('colds', 'NNS')
# ('collaborators', 'NNS')
# ('collages', 'NNS')
# ('collapses', 'VBZ')
# ('collars', 'NNS')
# ('colleagues', 'NNS')
# ('collections', 'NNS')
# ('collectors', 'NNS')
# ('collects', 'VBZ')
# ('colleges', 'NNS')
# ('collegians', 'NNS')
# ('collisions', 'NNS')
# ('colonels', 'NNS')
# ('colonials', 'NNS')
# ('colonies', 'NNS')
# ('colonists', 'NNS')
# ('coloreds', 'NNS')
# ('colors', 'NNS')
# ('colors', 'VBZ')
# ('colour-prints', 'NNS')
# ('colts', 'NNS')
# ('columbines', 'NNS')
# ('columnists', 'NNS')
# ('columns', 'NNS')
# ('comas', 'NNS')
# ('combatants', 'NNS')
# ('combinations', 'NNS')
# ('combines', 'VBZ')
# ('combustibles', 'NNS')
# ('comedians', 'NNS')
# ('comedies', 'NNS')
# ('comes', 'VBZ')
# ('cometh', 'VBZ')
# ('comets', 'NNS')
# ('comforts', 'NNS')
# ('comings', 'NNS')
# ('commanders', 'NNS')
# ('commands', 'NNS')
# ('commands', 'VBZ')
# ('commemorates', 'VBZ')
# ('commencements', 'NNS')
# ('commences', 'VBZ')
# ('commends', 'VBZ')
# ('commentaries', 'NNS')
# ('commentators', 'NNS')
# ('comments', 'NNS')
# ('comments', 'VBZ')
# ('commercials', 'NNS')
# ('commissioners', 'NNS')
# ('commissions', 'NNS')
# ('commitments', 'NNS')
# ('commits', 'VBZ')
# ('committeemen', 'NNS')
# ('committees', 'NNS')
# ('commodities', 'NNS')
# ('commoners', 'NNS')
# ('commonplaces', 'NNS')
# ('commonwealths', 'NNS')
# ('communes', 'NNS')
# ('communications', 'NNS')
# ('communicators', 'NNS')
# ('communiques', 'NNS')
# ('communities', 'NNS')
# ('commutes', 'VBZ')
# ('compacts', 'NNS')
# ('companies', 'NNS')
# ('companions', 'NNS')
# ('compares', 'VBZ')
# ('comparisons', 'NNS')
# ('compartments', 'NNS')
# ('compatriots', 'NNS')
# ('compels', 'VBZ')
# ('compensates', 'VBZ')
# ('compensations', 'NNS')
# ('competes', 'VBZ')
# ('competitors', 'NNS')
# ('compilations', 'NNS')
# ('complains', 'VBZ')
# ('complaints', 'NNS')
# ('complements', 'NNS')
# ('completes', 'VBZ')
# ('completions', 'NNS')
# ('complexes', 'NNS')
# ('complexities', 'NNS')
# ('complications', 'NNS')
# ('compliments', 'NNS')
# ('components', 'NNS')
# ('composers', 'NNS')
# ('composes', 'VBZ')
# ('composites', 'NNS')
# ('compositions', 'NNS')
# ('compounds', 'NNS')
# ('compounds', 'VBZ')
# ('compresses', 'NNS')
# ('compresses', 'VBZ')
# ('comprises', 'VBZ')
# ('compromises', 'NNS')
# ('compulsions', 'NNS')
# ('compulsives', 'NNS')
# ('computations', 'NNS')
# ('computers', 'NNS')
# ('computes', 'VBZ')
# ('comrades', 'NNS')
# ('conceals', 'VBZ')
# ('concedes', 'VBZ')
# ('conceits', 'NNS')
# ('conceives', 'VBZ')
# ('concentrates', 'NNS')
# ('concentrates', 'VBZ')
# ('concentrations', 'NNS')
# ('conceptions', 'NNS')
# ('concepts', 'NNS')
# ('concerns', 'NNS')
# ('concerns', 'VBZ')
# ('concerti', 'NNS')
# ('concertos', 'NNS')
# ('concerts', 'NNS')
# ('concessionaires', 'NNS')
# ('concessions', 'NNS')
# ('concludes', 'VBZ')
# ('conclusions', 'NNS')
# ('concurs', 'VBZ')
# ('condemns', 'VBZ')
# ('condicions', 'NNS')
# ('condiments', 'NNS')
# ('conditioners', 'NNS')
# ('conditions', 'NNS')
# ('condolences', 'NNS')
# ('conductors', 'NNS')
# ('conducts', 'NNS')
# ('conducts', 'VBZ')
# ('cones', 'NNS')
# ('confabulations', 'NNS')
# ('confederates', 'NNS')
# ('confederations', 'NNS')
# ('conferees', 'NNS')
# ('conferences', 'NNS')
# ('confers', 'VBZ')
# ('confesses', 'VBZ')
# ('confessionals', 'NNS')
# ('confessions', 'NNS')
# ('confidences', 'NNS')
# ('configurations', 'NNS')
# ('confinements', 'NNS')
# ('confines', 'NNS')
# ('confirms', 'VBZ')
# ('conflicts', 'NNS')
# ('conflicts', 'VBZ')
# ('conformists', 'NNS')
# ('conforms', 'VBZ')
# ('confreres', 'NNS')
# ('confrontations', 'NNS')
# ('confronts', 'VBZ')
# ('confuses', 'VBZ')
# ('confusions', 'NNS')
# ('congratulations', 'NNS')
# ('congregations', 'NNS')
# ('congressmen', 'NNS')
# ('conjectures', 'NNS')
# ('conjugates', 'NNS')
# ('conjunctions', 'NNS')
# ('conjures', 'VBZ')
# ('connections', 'NNS')
# ('connects', 'VBZ')
# ('connoisseurs', 'NNS')
# ('connotations', 'NNS')
# ('connotes', 'VBZ')
# ('conquerors', 'NNS')
# ('conquests', 'NNS')
# ('cons', 'NNS')
# ('consciences', 'NNS')
# ('consderations', 'NNS')
# ('consequences', 'NNS')
# ('conservatives', 'NNS')
# ('conserves', 'VBZ')
# ('considerations', 'NNS')
# ('considers', 'VBZ')
# ('consists', 'VBZ')
# ('consoles', 'NNS')
# ('consonants', 'NNS')
# ('conspiracies', 'NNS')
# ('conspirators', 'NNS')
# ('conspires', 'VBZ')
# ('constables', 'NNS')
# ('constants', 'NNS')
# ('constellations', 'NNS')
# ('constituencies', 'NNS')
# ('constituents', 'NNS')
# ('constitutes', 'VBZ')
# ('constitutions', 'NNS')
# ('constrictions', 'NNS')
# ('constrictors', 'NNS')
# ('constructions', 'NNS')
# ('consultants', 'NNS')
# ('consultations', 'NNS')
# ('consumers', 'NNS')
# ('consumes', 'VBZ')
# ('contacts', 'NNS')
# ('contacts', 'VBZ')
# ('containers', 'NNS')
# ('contains', 'VBZ')
# ('contemplates', 'VBZ')
# ('contemporaries', 'NNS')
# ('contends', 'VBZ')
# ('contentions', 'NNS')
# ('contents', 'NNS')
# ('contestants', 'NNS')
# ('contests', 'NNS')
# ('contexts', 'NNS')
# ('continents', 'NNS')
# ('contingencies', 'NNS')
# ('contingents', 'NNS')
# ('continues', 'VBZ')
# ('continuities', 'NNS')
# ('contours', 'NNS')
# ('contraceptives', 'NNS')
# ('contractors', 'NNS')
# ('contracts', 'NNS')
# ('contracts', 'VBZ')
# ('contradictions', 'NNS')
# ('contradicts', 'VBZ')
# ('contraptions', 'NNS')
# ('contrarieties', 'NNS')
# ('contrasts', 'NNS')
# ('contrasts', 'VBZ')
# ('contribs', 'NNS')
# ('contributes', 'VBZ')
# ('contributions', 'NNS')
# ('contributors', 'NNS')
# ('contrivances', 'NNS')
# ('controllers', 'NNS')
# ('controls', 'NNS')
# ('controls', 'VBZ')
# ('controversialists', 'NNS')
# ('controversies', 'NNS')
# ('contusions', 'NNS')
# ('conveniences', 'NNS')
# ('conventions', 'NNS')
# ('conversations', 'NNS')
# ('conversions', 'NNS')
# ('converts', 'NNS')
# ('conveys', 'VBZ')
# ('convictions', 'NNS')
# ('convicts', 'NNS')
# ('convulsions', 'NNS')
# ('cookies', 'NNS')
# ('cooks', 'NNS')
# ('coolers', 'NNS')
# ('coolnesses', 'NNS')
# ('cools', 'VBZ')
# ('cooperates', 'VBZ')
# ('cooperatives', 'NNS')
# ('coops', 'NNS')
# ('coordinates', 'NNS')
# ('coordinates', 'VBZ')
# ('copes', 'VBZ')
# ('copies', 'NNS')
# ('copings', 'NNS')
# ('copolymers', 'NNS')
# ('cops', 'NNS')
# ('copybooks', 'NNS')
# ('copyrights', 'NNS')
# ('cords', 'NNS')
# ('corduroys', 'NNS')
# ('cores', 'NNS')
# ('corkers', 'NNS')
# ('corks', 'NNS')
# ('corner-posts', 'NNS')
# ('corners', 'NNS')
# ('corns', 'NNS')
# ('corollaries', 'NNS')
# ('corporations', 'NNS')
# ('corpses', 'NNS')
# ('corrections', 'NNS')
# ('correlations', 'NNS')
# ('correspondents', 'NNS')
# ('corresponds', 'VBZ')
# ('corridors', 'NNS')
# ('corrugations', 'NNS')
# ('corrupts', 'VBZ')
# ('corticosteroids', 'NNS')
# ('cosmetics', 'NNS')
# ('cosmologists', 'NNS')
# ('cosponsors', 'VBZ')
# ('costs', 'NNS')
# ('costs', 'VBZ')
# ('costumes', 'NNS')
# ('cottages', 'NNS')
# ('couches', 'NNS')
# ('councils', 'NNS')
# ('counselors', 'NNS')
# ('counter-efforts', 'NNS')
# ('counter-moves', 'NNS')
# ('counter-successes', 'NNS')
# ('counterparts', 'NNS')
# ('counters', 'NNS')
# ('counties', 'NNS')
# ('countries', 'NNS')
# ('countrymen', 'NNS')
# ('counts', 'NNS')
# ('counts', 'VBZ')
# ('couplers', 'NNS')
# ('couples', 'NNS')
# ('coupons', 'NNS')
# ('coups', 'NNS')
# ('courses', 'NNS')
# ('courtiers', 'NNS')
# ('courts', 'NNS')
# ('courts', 'VBZ')
# ('courtyards', 'NNS')
# ('cousins', 'NNS')
# ('covenants', 'NNS')
# ('coverings', 'NNS')
# ('covers', 'NNS')
# ('covers', 'VBZ')
# ('coves', 'NNS')
# ('cow-people', 'NNS')
# ('cowbirds', 'NNS')
# ('cowboys', 'NNS')
# ('cowhands', 'NNS')
# ('coworkers', 'NNS')
# ('cowrtiers', 'NNS')
# ('cows', 'NNS')
# ('coxcombs', 'NNS')
# ('coyotes', 'NNS')
# ('crabs', 'NNS')
# ('crackers', 'NNS')
# ('crackles', 'VBZ')
# ('crackpots', 'NNS')
# ('cracks', 'NNS')
# ('cracks', 'VBZ')
# ('cradles', 'NNS')
# ('crafts', 'NNS')
# ('craftsmen', 'NNS')
# ('crags', 'NNS')
# ('cramps', 'NNS')
# ('cranberries', 'NNS')
# ('crannies', 'NNS')
# ('crashes', 'NNS')
# ('craters', 'NNS')
# ('crates', 'NNS')
# ('crawls', 'NNS')
# ('crayons', 'NNS')
# ('creaks', 'VBZ')
# ('creams', 'NNS')
# ('creases', 'NNS')
# ('creates', 'VBZ')
# ('creations', 'NNS')
# ('creators', 'NNS')
# ('creatures', 'NNS')
# ('credentials', 'NNS')
# ('creditors', 'NNS')
# ('credits', 'NNS')
# ('credits', 'VBZ')
# ('creeds', 'NNS')
# ('creeks', 'NNS')
# ('creepers', 'NNS')
# ('creeps', 'VBZ')
# ('crests', 'NNS')
# ('crevices', 'NNS')
# ('crewmen', 'NNS')
# ('crews', 'NNS')
# ('cribs', 'NNS')
# ('crickets', 'NNS')
# ('cries', 'NNS')
# ('cries', 'VBZ')
# ('crimes', 'NNS')
# ('criminals', 'NNS')
# ('crinkles', 'NNS')
# ('crises', 'NNS')
# ('criteria', 'NNS')
# ('criticisms', 'NNS')
# ('critics', 'NNS')
# ('critters', 'NNS')
# ('croaks', 'NNS')
# ('crofters', 'NNS')
# ('cronies', 'NNS')
# ('crooks', 'NNS')
# ('crops', 'NNS')
# ('crops', 'VBZ')
# ('cross-purposes', 'NNS')
# ('cross-striations', 'NNS')
# ('crossbars', 'NNS')
# ('crosses', 'NNS')
# ('crosses', 'VBZ')
# ('crossings', 'NNS')
# ('crossroads', 'NNS')
# ('crowds', 'NNS')
# ('crowns', 'NNS')
# ('crows', 'NNS')
# ('crudities', 'NNS')
# ('cruisers', 'NNS')
# ('cruises', 'NNS')
# ('crushers', 'NNS')
# ('crutches', 'NNS')
# ('crystallites', 'NNS')
# ('crystallographers', 'NNS')
# ('crystals', 'NNS')
# ('cubes', 'NNS')
# ('cubists', 'NNS')
# ('cudgels', 'NNS')
# ('cues', 'NNS')
# ('cufflinks', 'NNS')
# ('cuffs', 'NNS')
# ('cuirassiers', 'NNS')
# ('culminates', 'VBZ')
# ('culprits', 'NNS')
# ('cultivates', 'VBZ')
# ('cults', 'NNS')
# ('cultures', 'NNS')
# ('cupboards', 'NNS')
# ('cups', 'NNS')
# ('curbs', 'NNS')
# ('curds', 'NNS')
# ('cures', 'NNS')
# ('curls', 'NNS')
# ('currants', 'NNS')
# ('currencies', 'NNS')
# ('currents', 'NNS')
# ('curricula', 'NNS')
# ('curriculums', 'NNS')
# ('curses', 'NNS')
# ('curtains', 'NNS')
# ('curves', 'NNS')
# ('cushions', 'NNS')
# ('customers', 'NNS')
# ('customs', 'NNS')
# ('cutlets', 'NNS')
# ('cutouts', 'NNS')
# ('cuts', 'NNS')
# ('cuts', 'VBZ')
# ('cutters', 'NNS')
# ('cuttings', 'NNS')
# ('cycles', 'NNS')
# ('cycles', 'VBZ')
# ('cylinders', 'NNS')
# ('cynics', 'NNS')
# ('cysts', 'NNS')
# ('dabbles', 'VBZ')
# ('dack-rihs', 'NNS')
# ('dactyls', 'NNS')
# ('daffodils', 'NNS')
# ('dagers', 'NNS')
# ('daises', 'NNS')
# ('daisies', 'NNS')
# ('dales', 'NNS')
# ('damages', 'NNS')
# ('damages', 'VBZ')
# ('dams', 'NNS')
# ('dancers', 'NNS')
# ('dances', 'NNS')
# ('dances', 'VBZ')
# ('dangers', 'NNS')
# ('dares', 'VBZ')
# ('dashes', 'NNS')
# ('dashes', 'VBZ')
# ('data', 'NNS')
# ('dates', 'NNS')
# ('dates', 'VBZ')
# ('daughters', 'NNS')
# ('davits', 'NNS')
# ('dawns', 'VBZ')
# ('daylights', 'NNS')
# ('days', 'NNS')
# ('dazzles', 'VBZ')
# ('deadheads', 'NNS')
# ('deadlines', 'NNS')
# ('dealers', 'NNS')
# ('dealerships', 'NNS')
# ('dealings', 'NNS')
# ('deals', 'NNS')
# ('deals', 'VBZ')
# ('deans', 'NNS')
# ('deaths', 'NNS')
# ('debates', 'NNS')
# ('debentures', 'NNS')
# ('debs', 'NNS')
# ('debts', 'NNS')
# ('debuts', 'VBZ')
# ('decades', 'NNS')
# ('decays', 'VBZ')
# ('deceives', 'VBZ')
# ('decencies', 'NNS')
# ('decides', 'VBZ')
# ('decimals', 'NNS')
# ('decisions', 'NNS')
# ('decks', 'NNS')
# ('declarations', 'NNS')
# ('declares', 'VBZ')
# ('declinations', 'NNS')
# ('declines', 'NNS')
# ('declines', 'VBZ')
# ('decomposes', 'VBZ')
# ('decorations', 'NNS')
# ('decorators', 'NNS')
# ('decreases', 'NNS')
# ('decreases', 'VBZ')
# ('decrees', 'NNS')
# ('decrees', 'VBZ')
# ('dedicates', 'VBZ')
# ('deductibles', 'NNS')
# ('deductions', 'NNS')
# ('deeds', 'NNS')
# ('deeds', 'VBZ')
# ('deeps', 'NNS')
# ('deer', 'NNS')
# ('deerskins', 'NNS')
# ('defeatists', 'NNS')
# ('defeats', 'NNS')
# ('defects', 'NNS')
# ('defendants', 'NNS')
# ('defenders', 'NNS')
# ('defends', 'VBZ')
# ('defenses', 'NNS')
# ('deferents', 'NNS')
# ('deferments', 'NNS')
# ('deficiencies', 'NNS')
# ('deficits', 'NNS')
# ('defines', 'VBZ')
# ('definitions', 'NNS')
# ('deformities', 'NNS')
# ('degrees', 'NNS')
# ('deities', 'NNS')
# ('delays', 'NNS')
# ('delays', 'VBZ')
# ('delegates', 'NNS')
# ('delegations', 'NNS')
# ('deliberations', 'NNS')
# ('delicacies', 'NNS')
# ('delights', 'NNS')
# ('delights', 'VBZ')
# ('delimits', 'VBZ')
# ('delineaments', 'NNS')
# ('delinquents', 'NNS')
# ('delivers', 'VBZ')
# ('deltas', 'NNS')
# ('deltoids', 'NNS')
# ('demagogues', 'NNS')
# ('demands', 'NNS')
# ('demands', 'VBZ')
# ('demeans', 'VBZ')
# ('democracies', 'NNS')
# ('demons', 'NNS')
# ('demonstrates', 'VBZ')
# ('demonstrations', 'NNS')
# ('demonstratives', 'NNS')
# ('demonstrators', 'NNS')
# ('demoralizes', 'VBZ')
# ('denials', 'NNS')
# ('denies', 'VBZ')
# ('denominations', 'NNS')
# ('denominators', 'NNS')
# ('denotes', 'VBZ')
# ('denounces', 'VBZ')
# ('dens', 'NNS')
# ('densities', 'NNS')
# ('dentists', 'NNS')
# ('dentures', 'NNS')
# ('denunciations', 'NNS')
# ('departments', 'NNS')
# ('departs', 'VBZ')
# ('departures', 'NNS')
# ('dependents', 'NNS')
# ('depends', 'VBZ')
# ('deplores', 'VBZ')
# ('deportees', 'NNS')
# ('depositions', 'NNS')
# ('depositors', 'NNS')
# ('deposits', 'NNS')
# ('depots', 'NNS')
# ('depravities', 'NNS')
# ('depredations', 'NNS')
# ('depressants', 'NNS')
# ('depresses', 'VBZ')
# ('depressions', 'NNS')
# ('depressors', 'NNS')
# ('deprivations', 'NNS')
# ('depths', 'NNS')
# ('deputies', 'NNS')
# ('derails', 'NNS')
# ('derelicts', 'NNS')
# ('derivations', 'NNS')
# ('derives', 'VBZ')
# ('dervishes', 'NNS')
# ('descendants', 'NNS')
# ('descendents', 'NNS')
# ('descends', 'VBZ')
# ('describes', 'VBZ')
# ('descriptions', 'NNS')
# ('deserts', 'NNS')
# ('deserts', 'VBZ')
# ('deserves', 'VBZ')
# ('designates', 'VBZ')
# ('designations', 'NNS')
# ('designers', 'NNS')
# ('designs', 'NNS')
# ('designs', 'VBZ')
# ('desires', 'NNS')
# ('desires', 'VBZ')
# ('desks', 'NNS')
# ('desolations', 'NNS')
# ('desperadoes', 'NNS')
# ('despises', 'VBZ')
# ('despoilers', 'NNS')
# ('despots', 'NNS')
# ('desserts', 'NNS')
# ('destinies', 'NNS')
# ('destroyers', 'NNS')
# ('details', 'NNS')
# ('detectives', 'NNS')
# ('detectors', 'NNS')
# ('detergents', 'NNS')
# ('deteriorates', 'VBZ')
# ('determinants', 'NNS')
# ('determinations', 'NNS')
# ('determines', 'VBZ')
# ('detours', 'NNS')
# ('detractors', 'NNS')
# ('developers', 'NNS')
# ('developments', 'NNS')
# ('develops', 'VBZ')
# ('deviants', 'NNS')
# ('deviations', 'NNS')
# ('devices', 'NNS')
# ('devils', 'NNS')
# ('devotees', 'NNS')
# ('devotions', 'NNS')
# ('dewars', 'NNS')
# ('dewdrops', 'NNS')
# ('diagnosticians', 'NNS')
# ('diagonals', 'NNS')
# ('diagrams', 'NNS')
# ('dialectics', 'NNS')
# ('dialects', 'NNS')
# ('dialogues', 'NNS')
# ('dials', 'NNS')
# ('diameters', 'NNS')
# ('diamonds', 'NNS')
# ('diapers', 'NNS')
# ('diaphragms', 'NNS')
# ('diaries', 'NNS')
# ('diatoms', 'NNS')
# ('dice', 'NNS')
# ('dicks', 'NNS')
# ...
# ('swatches', 'NNS')
# ('swathings', 'NNS')
# ('swears', 'VBZ')
# ('sweat-suits', 'NNS')
# ('sweaters', 'NNS')
# ('sweepings', 'NNS')
# ('sweepstakes', 'NNS')
# ('sweethearts', 'NNS')
# ('sweetpeas', 'NNS')
# ('sweets', 'NNS')
# ('swellings', 'NNS')
# ('swells', 'NNS')
# ('swimmers', 'NNS')
# ('swine', 'NNS')
# ('swings', 'NNS')
# ('switches', 'NNS')
# ('switches', 'VBZ')
# ('swivels', 'VBZ')
# ('swoops', 'NNS')
# ('swoops', 'VBZ')
# ('swords', 'NNS')
# ('sycophants', 'NNS')
# ('syllables', 'NNS')
# ('symbolists', 'NNS')
# ('symbolizes', 'VBZ')
# ('symbols', 'NNS')
# ('sympathies', 'NNS')
# ('symphonies', 'NNS')
# ('symptoms', 'NNS')
# ('synagogues', 'NNS')
# ('synapses', 'NNS')
# ('synchronizers', 'NNS')
# ('syndicates', 'NNS')
# ('synonyms', 'NNS')
# ('synthesizes', 'VBZ')
# ('synthetics', 'NNS')
# ('systems', 'NNS')
# ('tabernacles', 'NNS')
# ('tablecloths', 'NNS')
# ('tables', 'NNS')
# ('tablespoonfuls', 'NNS')
# ('tablespoons', 'NNS')
# ('tablets', 'NNS')
# ('tabloids', 'NNS')
# ('taboos', 'NNS')
# ('tabulations', 'NNS')
# ('tackles', 'NNS')
# ('tactics', 'NNS')
# ('tadpoles', 'NNS')
# ('tags', 'NNS')
# ('tails', 'NNS')
# ('takeoffs', 'NNS')
# ('takes', 'VBZ')
# ('takings', 'NNS')
# ('talents', 'NNS')
# ('tales', 'NNS')
# ('talks', 'NNS')
# ('talks', 'VBZ')
# ('tallies', 'NNS')
# ('talons', 'NNS')
# ('tangents', 'NNS')
# ('tangos', 'NNS')
# ('tankers', 'NNS')
# ('tanks', 'NNS')
# ('tantrums', 'NNS')
# ('tapes', 'NNS')
# ('tapestries', 'NNS')
# ('tappets', 'NNS')
# ('taps', 'NNS')
# ('targets', 'NNS')
# ('tarpaulins', 'NNS')
# ('tasks', 'NNS')
# ('tassels', 'NNS')
# ('tastes', 'NNS')
# ('tastes', 'VBZ')
# ('taunts', 'NNS')
# ('taverns', 'NNS')
# ('taxes', 'NNS')
# ('taxi-ways', 'NNS')
# ('taxis', 'NNS')
# ('taxpayers', 'NNS')
# ('teachers', 'NNS')
# ('teaches', 'VBZ')
# ('teachings', 'NNS')
# ('teahouses', 'NNS')
# ('teammates', 'NNS')
# ('teams', 'NNS')
# ('teamsters', 'NNS')
# ('tears', 'NNS')
# ('teas', 'NNS')
# ('teaspoonfuls', 'NNS')
# ('teaspoons', 'NNS')
# ('teats', 'NNS')
# ('technicalities', 'NNS')
# ('technicians', 'NNS')
# ('techniques', 'NNS')
# ('teems', 'VBZ')
# ('teen-agers', 'NNS')
# ('teenagers', 'NNS')
# ('teens', 'NNS')
# ('teeth', 'NNS')
# ('tektites', 'NNS')
# ('telegrams', 'NNS')
# ('telegraphers', 'NNS')
# ('telephones', 'NNS')
# ('telescopes', 'NNS')
# ('teletypes', 'NNS')
# ('tellers', 'NNS')
# ('tells', 'VBZ')
# ('temperatures', 'NNS')
# ('tempers', 'NNS')
# ('temples', 'NNS')
# ('tempos', 'NNS')
# ('temptations', 'NNS')
# ('tempts', 'VBZ')
# ('tenants', 'NNS')
# ('tendencies', 'NNS')
# ('tendons', 'NNS')
# ('tends', 'VBZ')
# ('tenements', 'NNS')
# ('tenets', 'NNS')
# ('tenors', 'NNS')
# ('tens', 'NNS')
# ('tenses', 'NNS')
# ('tensions', 'NNS')
# ('tentacles', 'NNS')
# ('tenths', 'NNS')
# ('tents', 'NNS')
# ('tepees', 'NNS')
# ('teratologies', 'NNS')
# ('terminals', 'NNS')
# ('terminates', 'VBZ')
# ('termini', 'NNS')
# ('terms', 'NNS')
# ('terms', 'VBZ')
# ('terraces', 'NNS')
# ('terrains', 'NNS')
# ('terriers', 'NNS')
# ('terrifies', 'VBZ')
# ('territories', 'NNS')
# ('terrorists', 'NNS')
# ('terrours', 'NNS')
# ('testaments', 'NNS')
# ('testifies', 'VBZ')
# ('testimonials', 'NNS')
# ('testings', 'NNS')
# ('tests', 'NNS')
# ('tests', 'VBZ')
# ('tethers', 'NNS')
# ('tetrahalides', 'NNS')
# ('textbooks', 'NNS')
# ('textiles', 'NNS')
# ('texts', 'NNS')
# ('textures', 'NNS')
# ('thanks', 'NNS')
# ('thatches', 'NNS')
# ('theatergoers', 'NNS')
# ('theaters', 'NNS')
# ('theatres', 'NNS')
# ('theatricals', 'NNS')
# ('themes', 'NNS')
# ('theologian-philosophers', 'NNS')
# ('theologians', 'NNS')
# ('theoreticians', 'NNS')
# ('theories', 'NNS')
# ('theorists', 'NNS')
# ('theoriticians', 'NNS')
# ('therapies', 'NNS')
# ('therapists', 'NNS')
# ('therefores', 'NNS')
# ('thermocouples', 'NNS')
# ('thermometers', 'NNS')
# ('thermostats', 'NNS')
# ('theses', 'NNS')
# ('thespians', 'NNS')
# ('thickeners', 'NNS')
# ('thickens', 'VBZ')
# ('thickets', 'NNS')
# ('thicknesses', 'NNS')
# ('thieves', 'NNS')
# ('thighs', 'NNS')
# ('thills', 'NNS')
# ('things', 'NNS')
# ('thinkers', 'NNS')
# ('thinks', 'VBZ')
# ('thirds', 'NNS')
# ('thirties', 'NNS')
# ('thorns', 'NNS')
# ('thoroughfares', 'NNS')
# ('thoughts', 'NNS')
# ('thousands', 'NNS')
# ('thousandths', 'NNS')
# ('threads', 'NNS')
# ('threatens', 'VBZ')
# ('threats', 'NNS')
# ('three-fifths', 'NNS')
# ('three-fourths', 'NNS')
# ('three-quarters', 'NNS')
# ('threes', 'NNS')
# ('thrillers', 'NNS')
# ('thrills', 'NNS')
# ('thrives', 'VBZ')
# ('throats', 'NNS')
# ('throes', 'NNS')
# ('thrombi', 'NNS')
# ('thrones', 'NNS')
# ('throws', 'VBZ')
# ('thrusts', 'NNS')
# ('thrusts', 'VBZ')
# ('thruways', 'NNS')
# ('thuds', 'NNS')
# ('thugs', 'NNS')
# ('thumbs', 'NNS')
# ('thunderclaps', 'NNS')
# ('thyroids', 'NNS')
# ('tickets', 'NNS')
# ('ticks', 'NNS')
# ('tidbits', 'NNS')
# ('tidelands', 'NNS')
# ('tides', 'NNS')
# ('tidings', 'NNS')
# ('tiers', 'NNS')
# ('ties', 'NNS')
# ('ties', 'VBZ')
# ('tiles', 'NNS')
# ('tilts', 'VBZ')
# ('timberlands', 'NNS')
# ('timbers', 'NNS')
# ('time-servers', 'NNS')
# ('timers', 'NNS')
# ('times', 'NNS')
# ('times', 'VBZ')
# ('timetables', 'NNS')
# ('tines', 'NNS')
# ('tinkers', 'NNS')
# ('tints', 'NNS')
# ('tips', 'NNS')
# ('tirades', 'NNS')
# ('tires', 'NNS')
# ('tires', 'VBZ')
# ('tissues', 'NNS')
# ('titers', 'NNS')
# ('tithes', 'NNS')
# ('titles', 'NNS')
# ('tits', 'NNS')
# ('titters', 'NNS')
# ('toadies', 'NNS')
# ('toddlers', 'NNS')
# ('toe-tips', 'NNS')
# ('toes', 'NNS')
# ('togs', 'NNS')
# ('toilets', 'NNS')
# ('tokens', 'NNS')
# ('tolls', 'NNS')
# ('tomatoes', 'NNS')
# ('tombs', 'NNS')
# ('tombstones', 'NNS')
# ('tomes', 'NNS')
# ('tonalities', 'NNS')
# ('tones', 'NNS')
# ('tongs', 'NNS')
# ('tongues', 'NNS')
# ('tonics', 'NNS')
# ('tons', 'NNS')
# ('tools', 'NNS')
# ('topcoats', 'NNS')
# ('topics', 'NNS')
# ('toppings', 'NNS')
# ('tops', 'NNS')
# ('tops', 'VBZ')
# ('torches', 'NNS')
# ('tormenters', 'NNS')
# ('tornadoes', 'NNS')
# ('torpedoes', 'NNS')
# ('torquers', 'NNS')
# ('torrents', 'NNS')
# ('torsos', 'NNS')
# ('tortures', 'NNS')
# ('tortures', 'VBZ')
# ('tosses', 'NNS')
# ('totals', 'NNS')
# ('totals', 'VBZ')
# ('touchdowns', 'NNS')
# ('touches', 'NNS')
# ('touches', 'VBZ')
# ('touchstones', 'NNS')
# ('toughs', 'NNS')
# ('tourists', 'NNS')
# ('tournaments', 'NNS')
# ('tours', 'NNS')
# ('towboats', 'NNS')
# ('towels', 'NNS')
# ('towers', 'NNS')
# ('towers', 'VBZ')
# ('towns', 'NNS')
# ('townships', 'NNS')
# ('townsmen', 'NNS')
# ('toys', 'NNS')
# ('toys', 'VBZ')
# ('tracers', 'NNS')
# ('traces', 'NNS')
# ('traces', 'VBZ')
# ('tracings', 'NNS')
# ('tracks', 'NNS')
# ('tractors', 'NNS')
# ('tracts', 'NNS')
# ('trademarks', 'NNS')
# ('traders', 'NNS')
# ('trades', 'NNS')
# ('trades', 'VBZ')
# ('tradesmen', 'NNS')
# ('traditions', 'NNS')
# ('tragedians', 'NNS')
# ('tragedies', 'NNS')
# ('trailers', 'NNS')
# ('trails', 'NNS')
# ('traineeships', 'NNS')
# ('trains', 'NNS')
# ('trains', 'VBZ')
# ('traitors', 'NNS')
# ('traits', 'NNS')
# ('trances', 'NNS')
# ('tranquilizers', 'NNS')
# ('transactions', 'NNS')
# ('transcends', 'VBZ')
# ('transcripts', 'NNS')
# ('transducers', 'NNS')
# ('transferors', 'NNS')
# ('transfers', 'NNS')
# ('transfers', 'VBZ')
# ('transformers', 'NNS')
# ('transforms', 'VBZ')
# ('transfusions', 'NNS')
# ('transients', 'NNS')
# ('transistors', 'NNS')
# ('transitions', 'NNS')
# ('translates', 'VBZ')
# ('translations', 'NNS')
# ('transmits', 'VBZ')
# ('transoms', 'NNS')
# ('transports', 'NNS')
# ('transports', 'VBZ')
# ('trapdoors', 'NNS')
# ('trappings', 'NNS')
# ('traps', 'NNS')
# ('traps', 'VBZ')
# ('travelers', 'NNS')
# ('travellers', 'NNS')
# ('travelogues', 'NNS')
# ('travels', 'NNS')
# ('travels', 'VBZ')
# ('trays', 'NNS')
# ('treacheries', 'NNS')
# ('treasures', 'NNS')
# ('treasuries', 'NNS')
# ('treaties', 'NNS')
# ('treatments', 'NNS')
# ('treats', 'NNS')
# ('treats', 'VBZ')
# ('tree-clumps', 'NNS')
# ('trees', 'NNS')
# ('treetops', 'NNS')
# ('trellises', 'NNS')
# ('trembles', 'VBZ')
# ('trenchermen', 'NNS')
# ('trenches', 'NNS')
# ('trends', 'NNS')
# ('trespasses', 'NNS')
# ('trestles', 'NNS')
# ('trials', 'NNS')
# ('triangles', 'NNS')
# ('tribes', 'NNS')
# ('tribesmen', 'NNS')
# ('tribunals', 'NNS')
# ('tributes', 'NNS')
# ('tricks', 'NNS')
# ('tries', 'NNS')
# ('tries', 'VBZ')
# ('trimmings', 'NNS')
# ('trims', 'NNS')
# ('trinkets', 'NNS')
# ('triplets', 'NNS')
# ('tripods', 'NNS')
# ('trips', 'NNS')
# ('triumphs', 'NNS')
# ('trivia', 'NNS')
# ('trobles', 'NNS')
# ('trolls', 'NNS')
# ('troopers', 'NNS')
# ('troops', 'NNS')
# ('troopships', 'NNS')
# ('trophies', 'NNS')
# ('tropics', 'NNS')
# ('troubles', 'NNS')
# ('troughs', 'NNS')
# ('troupes', 'NNS')
# ('trousers', 'NNS')
# ('trousers-pockets', 'NNS')
# ('truckers', 'NNS')
# ('trucks', 'NNS')
# ('trumps', 'NNS')
# ('trunks', 'NNS')
# ('trusses', 'NNS')
# ('trustees', 'NNS')
# ('trusteth', 'VBZ')
# ('trusts', 'NNS')
# ('trusts', 'VBZ')
# ('truths', 'NNS')
# ('tsunami', 'NNS')
# ('tubers', 'NNS')
# ('tubes', 'NNS')
# ('tubs', 'NNS')
# ('tubules', 'NNS')
# ('tufts', 'NNS')
# ('tulips', 'NNS')
# ('tumbles', 'NNS')
# ('tumbrels', 'NNS')
# ('tumors', 'NNS')
# ('tumours', 'NNS')
# ('tunes', 'NNS')
# ('tunnels', 'NNS')
# ('turbinates', 'NNS')
# ('turbines', 'NNS')
# ('turkeys', 'NNS')
# ('turnings', 'NNS')
# ('turnips', 'NNS')
# ('turnouts', 'NNS')
# ('turnpikes', 'NNS')
# ('turns', 'NNS')
# ('turns', 'VBZ')
# ('turrets', 'NNS')
# ('turtlebacks', 'NNS')
# ('turtles', 'NNS')
# ('tusks', 'NNS')
# ('tutorials', 'NNS')
# ('tutors', 'NNS')
# ('twenties', 'NNS')
# ('twigs', 'NNS')
# ('twinges', 'NNS')
# ('twins', 'NNS')
# ('twister-coners', 'NNS')
# ('twists', 'NNS')
# ('two-by-fours', 'NNS')
# ('two-inches', 'NNS')
# ('two-seaters', 'NNS')
# ('two-thirds', 'NNS')
# ('two-weeks', 'NNS')
# ('twos', 'NNS')
# ('types', 'NNS')
# ('typewriters', 'NNS')
# ('tyrants', 'NNS')
# ('ulcerations', 'NNS')
# ('umbrellas', 'NNS')
# ('uncertainties', 'NNS')
# ('uncles', 'NNS')
# ('under-achievers', 'NNS')
# ('underachievers', 'NNS')
# ('underclothes', 'NNS')
# ('undergoes', 'VBZ')
# ('undergraduates', 'NNS')
# ('underlies', 'VBZ')
# ('underpins', 'VBZ')
# ('understandings', 'NNS')
# ('understands', 'VBZ')
# ('understates', 'VBZ')
# ('undertakes', 'VBZ')
# ('undertakings', 'NNS')
# ('underwriters', 'NNS')
# ('unfolds', 'VBZ')
# ('unfortunates', 'NNS')
# ('unifications', 'NNS')
# ('unifies', 'VBZ')
# ('uniforms', 'NNS')
# ('unions', 'NNS')
# ('unites', 'VBZ')
# ('unities', 'NNS')
# ('units', 'NNS')
# ('universals', 'NNS')
# ('universities', 'NNS')
# ('unknowns', 'NNS')
# ('unloads', 'VBZ')
# ('unlocks', 'VBZ')
# ('unoriginals', 'NNS')
# ('upholders', 'NNS')
# ('uplands', 'NNS')
# ('upperclassmen', 'NNS')
# ('uprisings', 'NNS')
# ('ups', 'NNS')
# ('upsets', 'NNS')
# ('upsets', 'VBZ')
# ('upshots', 'NNS')
# ('urethanes', 'NNS')
# ('urgencies', 'NNS')
# ('urges', 'NNS')
# ('urges', 'VBZ')
# ('urgings', 'NNS')
# ('urinals', 'NNS')
# ('urns', 'NNS')
# ('usages', 'NNS')
# ('users', 'NNS')
# ('uses', 'NNS')
# ('uses', 'VBZ')
# ('utensils', 'NNS')
# ('utilities', 'NNS')
# ('utilizes', 'VBZ')
# ('utopians', 'NNS')
# ('utopias', 'NNS')
# ('utterances', 'NNS')
# ('vacancies', 'NNS')
# ('vacationers', 'NNS')
# ('vacations', 'NNS')
# ('vagaries', 'NNS')
# ('valleys', 'NNS')
# ('valuations', 'NNS')
# ('value-judgments', 'NNS')
# ('value-orientations', 'NNS')
# ('value-problems', 'NNS')
# ('values', 'NNS')
# ('values', 'VBZ')
# ('valves', 'NNS')
# ('vampires', 'NNS')
# ('vandals', 'NNS')
# ('vanishes', 'VBZ')
# ('vanities', 'NNS')
# ('vantage-points', 'NNS')
# ('variables', 'NNS')
# ('variations', 'NNS')
# ('varies', 'VBZ')
# ('varieties', 'NNS')
# ('varnishes', 'NNS')
# ('vases', 'NNS')
# ('vaults', 'NNS')
# ('vectors', 'NNS')
# ('veers', 'VBZ')
# ('vegetables', 'NNS')
# ('vehicles', 'NNS')
# ('veils', 'NNS')
# ('veins', 'NNS')
# ('velocities', 'NNS')
# ('vendors', 'NNS')
# ('ventilates', 'VBZ')
# ('ventricles', 'NNS')
# ('vents', 'NNS')
# ('ventures', 'NNS')
# ('verandas', 'NNS')
# ('verbenas', 'NNS')
# ('verbs', 'NNS')
# ('verses', 'NNS')
# ('versions', 'NNS')
# ('vertebrae', 'NNS')
# ('vertebrates', 'NNS')
# ('vessels', 'NNS')
# ('vestments', 'NNS')
# ('vests', 'NNS')
# ('veterans', 'NNS')
# ('veterinarians', 'NNS')
# ('vexes', 'VBZ')
# ('vibes', 'NNS')
# ('vice-presidents', 'NNS')
# ('vices', 'NNS')
# ('vicissitudes', 'NNS')
# ('victims', 'NNS')
# ('victories', 'NNS')
# ('victuals', 'NNS')
# ('vies', 'VBZ')
# ('viewers', 'NNS')
# ('viewpoints', 'NNS')
# ('views', 'NNS')
# ('views', 'VBZ')
# ('villagers', 'NNS')
# ('villages', 'NNS')
# ('villains', 'NNS')
# ('vines', 'NNS')
# ('vineyards', 'NNS')
# ('violates', 'VBZ')
# ('violations', 'NNS')
# ('violets', 'NNS')
# ('violinists', 'NNS')
# ('violins', 'NNS')
# ('virtues', 'NNS')
# ('viscera', 'NNS')
# ('visions', 'NNS')
# ('visitations', 'NNS')
# ('visitors', 'NNS')
# ('visits', 'NNS')
# ('visits', 'VBZ')
# ('vistas', 'NNS')
# ('visualizes', 'VBZ')
# ('vitals', 'NNS')
# ('vitamins', 'NNS')
# ('vitiates', 'VBZ')
# ('vocabularies', 'NNS')
# ('vocalists', 'NNS')
# ('vocals', 'NNS')
# ('voices', 'NNS')
# ('voids', 'VBZ')
# ('volcanos', 'NNS')
# ('voltages', 'NNS')
# ('volts', 'NNS')
# ('volumes', 'NNS')
# ('volunteers', 'NNS')
# ('voters', 'NNS')
# ('votes', 'NNS')
# ('votes', 'VBZ')
# ('vouchers', 'NNS')
# ('vouchsafes', 'VBZ')
# ('vowels', 'NNS')
# ('vows', 'NNS')
# ('vows', 'VBZ')
# ('voyages', 'NNS')
# ('wads', 'NNS')
# ('waffles', 'NNS')
# ('wage-rates', 'NNS')
# ('wages', 'NNS')
# ('wagons', 'NNS')
# ('wails', 'NNS')
# ('waiters', 'NNS')
# ('waitresses', 'NNS')
# ('waits', 'VBZ')
# ('wakes', 'VBZ')
# ('wales', 'NNS')
# ('walks', 'NNS')
# ('walks', 'VBZ')
# ('walkways', 'NNS')
# ('wall-flowers', 'NNS')
# ('wallpapers', 'NNS')
# ('walls', 'NNS')
# ('walnuts', 'NNS')
# ('wanderers', 'NNS')
# ('wanderings', 'NNS')
# ('wanders', 'VBZ')
# ('wants', 'NNS')
# ('wants', 'VBZ')
# ('ward-heelers', 'NNS')
# ('ward-personnel', 'NNS')
# ('wardens', 'NNS')
# ('wards', 'NNS')
# ('warehouses', 'NNS')
# ('wares', 'NNS')
# ('warms', 'VBZ')
# ('warnings', 'NNS')
# ('warns', 'VBZ')
# ('warrants', 'NNS')
# ('warriors', 'NNS')
# ('wars', 'NNS')
# ('warships', 'NNS')
# ('warts', 'NNS')
# ('warys', 'NNS')
# ('wash-outs', 'NNS')
# ('washes', 'NNS')
# ('washings', 'NNS')
# ('wastes', 'NNS')
# ('watchers', 'NNS')
# ('watches', 'NNS')
# ('watches', 'VBZ')
# ('watchings', 'NNS')
# ('watchmen', 'NNS')
# ('watercolorists', 'NNS')
# ('watercolors', 'NNS')
# ('waterfalls', 'NNS')
# ('waterflows', 'NNS')
# ('waters', 'NNS')
# ('watersheds', 'NNS')
# ('waterways', 'NNS')
# ('wattles', 'NNS')
# ('wavelengths', 'NNS')
# ('wavers', 'NNS')
# ('waves', 'NNS')
# ('ways', 'NNS')
# ('weakens', 'VBZ')
# ('weaknesses', 'NNS')
# ('weapons', 'NNS')
# ('wears', 'VBZ')
# ('weaves', 'NNS')
# ('weddings', 'NNS')
# ('weeds', 'NNS')
# ('week-ends', 'NNS')
# ('weekends', 'NNS')
# ('weeklies', 'NNS')
# ('weeks', 'NNS')
# ('weighs', 'VBZ')
# ('weights', 'NNS')
# ('weights', 'VBZ')
# ('weirs', 'NNS')
# ('welcomes', 'VBZ')
# ('well-springs', 'NNS')
# ('well-wishers', 'NNS')
# ('wells', 'NNS')
# ('welts', 'NNS')
# ('wetlands', 'NNS')
# ('wharves', 'NNS')
# ('what-nots', 'NNS')
# ('wheels', 'NNS')
# ('wheezes', 'NNS')
# ('wherefores', 'NNS')
# ('whims', 'NNS')
# ('whiplashes', 'NNS')
# ('whipping-boys', 'NNS')
# ('whips', 'NNS')
# ('whiskers', 'NNS')
# ('whisperings', 'NNS')
# ('whispers', 'NNS')
# ('whitens', 'VBZ')
# ('whites', 'NNS')
# ('whitetail', 'NNS')
# ('wholes', 'NNS')
# ('wholesalers', 'NNS')
# ('whoppers', 'NNS')
# ('whores', 'NNS')
# ('whorls', 'NNS')
# ('whyfores', 'NNS')
# ('wickets', 'NNS')
# ('widens', 'VBZ')
# ('widows', 'NNS')
# ('widths', 'NNS')
# ('wieners', 'NNS')
# ('wiles', 'NNS')
# ('wills', 'NNS')
# ('winches', 'NNS')
# ('windbreaks', 'NNS')
# ('winders', 'NNS')
# ('winding-clothes', 'NNS')
# ('windowpanes', 'NNS')
# ('windows', 'NNS')
# ('winds', 'NNS')
# ('winds', 'VBZ')
# ('wines', 'NNS')
# ('wings', 'NNS')
# ('winners', 'NNS')
# ('winnings', 'NNS')
# ('winos', 'NNS')
# ('wins', 'NNS')
# ('wins', 'VBZ')
# ('winters', 'NNS')
# ('wires', 'NNS')
# ('wishes', 'NNS')
# ('wishes', 'VBZ')
# ('wisps', 'NNS')
# ('witches', 'NNS')
# ('withes', 'NNS')
# ('withstands', 'VBZ')
# ('witnesses', 'NNS')
# ('wits', 'NNS')
# ('wives', 'NNS')
# ('wolves', 'NNS')
# ('women', 'NNS')
# ('wonders', 'NNS')
# ('wonders', 'VBZ')
# ('woodcutters', 'NNS')
# ('woods', 'NNS')
# ('woolworkers', 'NNS')
# ('wops', 'VBZ')
# ('word-games', 'NNS')
# ('words', 'NNS')
# ('work-outs', 'NNS')
# ('workers', 'NNS')
# ('workingmen', 'NNS')
# ('workings', 'NNS')
# ('workmen', 'NNS')
# ('workouts', 'NNS')
# ('works', 'NNS')
# ('works', 'VBZ')
# ('workshops', 'NNS')
# ('worlds', 'NNS')
# ('worms', 'NNS')
# ('worries', 'NNS')
# ('worries', 'VBZ')
# ('worsens', 'VBZ')
# ('worshippers', 'NNS')
# ('wounds', 'NNS')
# ('wrappers', 'NNS')
# ('wraps', 'NNS')
# ('wreaths', 'NNS')
# ('wrenches', 'NNS')
# ('wrenches', 'VBZ')
# ('wrestles', 'NNS')
# ('wrestlings', 'NNS')
# ('wrings', 'VBZ')
# ('wrinkles', 'NNS')
# ('wrists', 'NNS')
# ('writers', 'NNS')
# ('writes', 'VBZ')
# ('writings', 'NNS')
# ('writs', 'NNS')
# ('wrongs', 'NNS')
# ('x-rays', 'NNS')
# ('xylophones', 'NNS')
# ('yachtels', 'NNS')
# ('yachters', 'NNS')
# ('yachts', 'NNS')
# ('yachtsmen', 'NNS')
# ('yaks', 'NNS')
# ('yards', 'NNS')
# ('yarns', 'NNS')
# ('yassuhs', 'NNS')
# ('yaws', 'NNS')
# ('yd.', 'NNS')
# ('yearnings', 'NNS')
# ('years', 'NNS')
# ('yeasts', 'NNS')
# ('yelps', 'NNS')
# ('yields', 'NNS')
# ('yields', 'VBZ')
# ('yokels', 'NNS')
# ('youngsters', 'NNS')
# ('youth', 'NNS')
# ('youths', 'NNS')
# ('yrs.', 'NNS')
# ('zeros', 'NNS')
# ('zlotys', 'NNS')
# ('zombies', 'NNS')
# ('zones', 'NNS')
# ('zooms', 'VBZ')

# %% [markdown]
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form `IN+AT+NN`, separated by semicolons

# %% [markdown]
# #### Goal
# we're looking for sequences of three words that match the pattern 'IN' (preposition), 'AT' (article), and 'NN' (noun).
# #### Explanations
#
# - IN: This is a tag for prepositions. Examples of words with this tag might be "in", "on", "at", "with", etc.
#
# - AT: This tag is for the singular article, most commonly "the".
#
# - NN: This is a tag for singular nouns. Examples could be "dog", "house", "book", etc.
#
# ##### - Examples:
# - "in the house"
# - "on the table"
# - "with the pen"

# %%
# Get the tagged words from the Brown corpus
tagged_words = brown.tagged_words()
# Initialize an empty set to store our prepositional phrases.
# We're using a set to automatically ensure that each phrase is distinct.
distinct_phrases = set()

# Loop through the corpus while maintaining an index
for i in range(len(tagged_words) - 2):  # -2 is to avoid an "out of range" error on the last two words.
    # Check for the IN+AT+NN pattern
    if (tagged_words[i][1] == 'IN' and 
        tagged_words[i+1][1] == 'AT' and 
        tagged_words[i+2][1] == 'NN'):
        # If they do, form the phrase and add it to our set.
        phrase = " ".join([tagged_words[i][0], tagged_words[i+1][0], tagged_words[i+2][0]])
        distinct_phrases.add(phrase)

# Sort the phrases alphabetically and print them separated by semicolons
print("; ".join(sorted(distinct_phrases)))
# Out:
# 'bout the saddle; 'ceptin' the light; About the murder; Above the tongue; Across the bay; Across the bridge; Across the front; Across the road; Across the street; Across the table; Across the way; After a conversation; After a day; After a dinner; After a flood; After a minute; After a moment; After a pause; After a reception; After a roundup; After a sort; After a supper; After a time; After a while; After a year; After an earthquake; After every money; After every session; After the collapse; After the demise; After the diagnosing; After the game; After the meal; After the meeting; After the pegboard; After the soil; After the spate; After the storm; After the war; Against the ruin; Along the way; Amid a shortage; Amid the crackle; Among the policy; Around the billiard; Around the table; As a result; At a ceremony; At a minimum; At a nod; At a party; At a rate; At a reception; At a siding; At no time; At the Seashore; At the adoption; At the age; At the base; At the beginning; At the bottom; At the close; At the conclusion; At the door; At the doorway; At the edge; At the end; At the entrance; At the gate; At the head; At the heart; At the height; At the inn; At the inquest; At the insistence; At the landing; At the meeting; At the moment; At the nadir; At the opening; At the order; At the outset; At the peak; At the point; At the rate; At the rear; At the risk; At the scene; At the sight; At the start; At the time; At the top; At the trial; At the workshop; Below the fort; Beneath the dome; Besides the bundle; Besides the lack; Besides the presence; Between the telephone; Beyond the forest; Beyond the stockade; By a combination; By an effort; By the age; By the death; By the end; By the look; By the middle; By the time; By the use; By the way; Concerning the sentence; Considering the nature; Considering the state; Despite an ambiguity; Despite the clarity; Despite the excitement; Despite the fact; Despite the hopelessness; Despite the lip; Despite the opposition; Despite the recession; Despite the rejection; Down the boulevard; Down the tree; During a round; During a sojourn; During the assignment; During the biennium; During the course; During the decade; During the discharge; During the election; During the excitement; During the making; During the month; During the morning; During the night; During the pension; During the period; During the quarrel; During the rest; During the return; During the summer; During the trial; During the trip; During the war; During the year; Following the term; For a chemical; For a man; For a minute; For a moment; For a number; For a resort; For a steak; For a time; For a while; For a year; For an anthropologist; For an antique; For an engine; For an example; For an experiment; For an instant; For every person; For the albumin; For the army; For the boy; For the case; For the convenience; For the dignity; For the figure; For the future; For the government; For the industry; For the interpretation; For the low-temperature; For the maintenance; For the marksman; For the moment; For the occasion; For the present; For the president; For the prevention; For the purpose; For the reason; For the remainder; For the school; For the treatment; For the use; For the vertex; For the year; From a man; From a pen; From an exercise; From the back; From the beginning; From the brightness; From the coil; From the collection; From the crowd; From the curio; From the equilibrium; From the evidence; From the luggage; From the man; From the moment; From the night; From the outset; From the outside; From the point; From the standpoint; From the time; From the town; From the volume; From the way; From the wealth; In a B; In a book; In a camp; In a climate; In a controversy; In a course; In a flash; In a fraction; In a frenzy; In a kind; In a letter; In a matter; In a minute; In a neighborhood; In a sample; In a saucepan; In a sense; In a series; In a set; In a society; In a story; In a stream; In a succession; In a ...

# %% [markdown]
# ### Exercise 7
#
# Write a function `prec_adv(word, text)` that returns an alphabetically sorted list of distinct adverbs that precede `word` in `text`. Use this function to find out which adverbs precede the words "love", "like", and "prefer" in the Brown corpus.

# %% [markdown]
# ### Goal:
# To implement funcation that give word and text and returns all list of all the adverbs the comes before that word, which is sorted in an alphabetically order.

# %%
def prec_adv(word, text):
    # 1. Initializing an empty set to store the adverbs that precede the given word.
    preceding_adverbs = set()

    # 2. Iterating over the text, which is assumed to be a list of word-tag pairs.
    for i, (current_word, tag) in enumerate(text):
        # Checking if we are at the beginning of the text to avoid an IndexError later.
        if i == 0:
            continue

        # 3. Checking if the current word matches the word we're looking for.
        if current_word == word:
            # Getting the word and tag of the preceding word.
            prev_word, prev_tag = text[i-1]

            # 4. Checking if the preceding word is an adverb (based on the tag "RB").
            if prev_tag == "RB":
                # If it is, we add it to our set of preceding adverbs.
                preceding_adverbs.add(prev_word)

    # 5. Finally, we convert the set to a list, sort it, and return it.
    return sorted(list(preceding_adverbs))

# %%
# Testing the function on the words "love", "like", and "prefer"
words_to_check = ["love", "like", "prefer"]
for word in words_to_check:
    print(f"Adverbs that precede '{word}': {prec_adv(word, brown.tagged_words())}")
# Out:
# Adverbs that precede 'love': ['always', 'dearly', 'just']
# Adverbs that precede 'like': ['Jist', 'Just', 'Kinda', 'abreast', 'almost', 'alone', 'always', 'around', 'by', 'close', 'deceptively', 'even', 'exactly', 'gloriously', 'here', 'increasingly', 'jist', 'just', 'much', 'often', 'particularly', 'quick', 'rather', 'remarkably', 'roughly', 'simply', 'so', 'somewhat', 'sure', 'there', 'together', 'wildly', 'yet']
# Adverbs that precede 'prefer': ['generally', 'much', 'spontaneously']
